# %% [markdown]
# # Setting up and Initialization
#
# **Note:** Most of the times it is needed to reinitializate the enviorment to correctly execute the whole program due to problems on importing libraries. If after executing the first cell of the *Code* section (third cell from the beginning), any error appears, please, reinitializate the enviorment and execute everything again.

# %% [markdown]
# # init

# %%
#Set up and import all libraries and utilities needed to execute the Pommerman project
import os
import sys
import numpy as np

#Download Pommerman enviorment from the repository
# !git clone https://github.com/esbenlkruse/Pommerman

os.chdir('Pommerman')
os.chdir('playground')

# !python setup.py install

from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# !pip install emoji

# install gym
! pip install git+https://github.com/openai/gym
# Out:
# fatal: destination path 'Pommerman' already exists and is not an empty directory.
# running install
# running bdist_egg
# running egg_info
# writing pommerman.egg-info/PKG-INFO
# writing dependency_links to pommerman.egg-info/dependency_links.txt
# writing entry points to pommerman.egg-info/entry_points.txt
# writing requirements to pommerman.egg-info/requires.txt
# writing top-level names to pommerman.egg-info/top_level.txt
# reading manifest file 'pommerman.egg-info/SOURCES.txt'
# writing manifest file 'pommerman.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pommerman
# copying build/lib/pommerman/characters.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/cli/train_with_tensorforce.py -> build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/cli/run_battle.py -> build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/cli/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/cli
# creating build/bdist.linux-x86_64/egg/pommerman/runner
# copying build/lib/pommerman/runner/docker_agent_runner.py -> build/bdist.linux-x86_64/egg/pommerman/runner
# copying build/lib/pommerman/runner/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/runner
# copying build/lib/pommerman/forward_model.py -> build/bdist.linux-x86_64/egg/pommerman
# copying build/lib/pommerman/__init__.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent0.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Skull.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Wood.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-5.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Flames.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-3.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-7.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/X-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-10.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent1-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-2.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent0-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-1.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-6.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent2-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/AgentDummy.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent2.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-8.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent1.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Kick.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/IncrRange.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Fog.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent3-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/AgentDummy-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/ExtraBomb.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Passage.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-9.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Cousine-Regular.ttf -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent3.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Rigid.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-4.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/constants.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/base_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/http_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/player_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/simple_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/random_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/tensorforce_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/docker_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/graphics.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/helpers
# copying build/lib/pommerman/helpers/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/helpers
# copying build/lib/pommerman/utility.py -> build/bdist.linux-x86_64/egg/pommerman
# copying build/lib/pommerman/configs.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/v0.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/v2.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/v1.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/characters.py to characters.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/cli/train_with_tensorforce.py to train_with_tensorforce.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/cli/run_battle.py to run_battle.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/cli/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/runner/docker_agent_runner.py to docker_agent_runner.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/runner/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/forward_model.py to forward_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/constants.py to constants.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/base_agent.py to base_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/http_agent.py to http_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/player_agent.py to player_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/simple_agent.py to simple_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/random_agent.py to random_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/tensorforce_agent.py to tensorforce_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/docker_agent.py to docker_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/graphics.py to graphics.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/helpers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/utility.py to utility.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/configs.py to configs.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/v0.py to v0.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/v2.py to v2.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/v1.py to v1.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/pommerman-0.2.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pommerman-0.2.0-py3.6.egg
# removing '/usr/local/lib/python3.6/dist-packages/pommerman-0.2.0-py3.6.egg' (and everything under it)
# creating /usr/local/lib/python3.6/dist-packages/pommerman-0.2.0-py3.6.egg
# Extracting pommerman-0.2.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# pommerman 0.2.0 is already the active version in easy-install.pth
# Installing pom_battle script to /usr/local/bin
# Installing pom_tf_battle script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pommerman-0.2.0-py3.6.egg
# Processing dependencies for pommerman==0.2.0
# Searching for pylint==1.9.3
# Best match: pylint 1.9.3
# Processing pylint-1.9.3-py3.6.egg
# pylint 1.9.3 is already the active version in easy-install.pth
# Installing epylint script to /usr/local/bin
# Installing pylint script to /usr/local/bin
# Installing symilar script to /usr/local/bin
# Installing pyreverse script to /usr/local/bin
# Installing epylint script to /usr/local/bin
# Installing pylint script to /usr/local/bin
# Installing pyreverse script to /usr/local/bin
# Installing symilar script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/pylint-1.9.3-py3.6.egg
# Searching for isort==4.3.4
# Best match: isort 4.3.4
# Processing isort-4.3.4-py3.6.egg
# isort 4.3.4 is already the active version in easy-install.pth
# Installing isort script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/isort-4.3.4-py3.6.egg
# Searching for astroid==1.6.5
# Best match: astroid 1.6.5
# Processing astroid-1.6.5-py3.6.egg
# astroid 1.6.5 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/astroid-1.6.5-py3.6.egg
# Searching for jsonmerge==1.5.2
# Best match: jsonmerge 1.5.2
# Processing jsonmerge-1.5.2-py3.6.egg
# jsonmerge 1.5.2 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/jsonmerge-1.5.2-py3.6.egg
# Searching for requests==2.18.4
# Best match: requests 2.18.4
# Adding requests 2.18.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Flask==0.12.4
# Best match: Flask 0.12.4
# Processing Flask-0.12.4-py3.6.egg
# Flask 0.12.4 is already the active version in easy-install.pth
# Installing flask script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/Flask-0.12.4-py3.6.egg
# Searching for ruamel.yaml==0.15.81
# Best match: ruamel.yaml 0.15.81
# Processing ruamel.yaml-0.15.81-py3.6-linux-x86_64.egg
# ruamel.yaml 0.15.81 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/ruamel.yaml-0.15.81-py3.6-linux-x86_64.egg
# Searching for Pillow==5.3.0
# Best match: Pillow 5.3.0
# Processing Pillow-5.3.0-py3.6-linux-x86_64.egg
# Pillow 5.3.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/Pillow-5.3.0-py3.6-linux-x86_64.egg
# Searching for scipy==1.1.0
# Best match: scipy 1.1.0
# Adding scipy 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for gym==0.10.9
# Best match: gym 0.10.9
# Adding gym 0.10.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for docker==3.6.0
# Best match: docker 3.6.0
# Processing docker-3.6.0-py3.6.egg
# docker 3.6.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/docker-3.6.0-py3.6.egg
# Searching for six==1.11.0
# Best match: six 1.11.0
# Adding six 1.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for mccabe==0.6.1
# Best match: mccabe 0.6.1
# Processing mccabe-0.6.1-py3.6.egg
# mccabe 0.6.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/mccabe-0.6.1-py3.6.egg
# Searching for wrapt==1.10.11
# Best match: wrapt 1.10.11
# Adding wrapt 1.10.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for lazy-object-proxy==1.3.1
# Best match: lazy-object-proxy 1.3.1
# Processing lazy_object_proxy-1.3.1-py3.6-linux-x86_64.egg
# lazy-object-proxy 1.3.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/lazy_object_proxy-1.3.1-py3.6-linux-x86_64.egg
# Searching for jsonschema==2.6.0
# Best match: jsonschema 2.6.0
# Adding jsonschema 2.6.0 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.6
# Best match: idna 2.6
# Adding idna 2.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2018.11.29
# Best match: certifi 2018.11.29
# Adding certifi 2018.11.29 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.22
# Best match: urllib3 1.22
# Adding urllib3 1.22 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for itsdangerous==1.1.0
# Best match: itsdangerous 1.1.0
# Adding itsdangerous 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Click==7.0
# Best match: Click 7.0
# Adding Click 7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Werkzeug==0.14.1
# Best match: Werkzeug 0.14.1
# Adding Werkzeug 0.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.10
# Best match: Jinja2 2.10
# Adding Jinja2 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.14.6
# Best match: numpy 1.14.6
# Adding numpy 1.14.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyglet==1.3.2
# Best match: pyglet 1.3.2
# Adding pyglet 1.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for websocket-client==0.54.0
# Best match: websocket-client 0.54.0
# Processing websocket_client-0.54.0-py3.6.egg
# websocket-client 0.54.0 is already the active version in easy-install.pth
# Installing wsdump.py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/websocket_client-0.54.0-py3.6.egg
# Searching for docker-pycreds==0.4.0
# Best match: docker-pycreds 0.4.0
# Processing docker_pycreds-0.4.0-py3.6.egg
# docker-pycreds 0.4.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/docker_pycreds-0.4.0-py3.6.egg
# Searching for MarkupSafe==1.1.0
# Best match: MarkupSafe 1.1.0
# Adding MarkupSafe 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for future==0.16.0
# Best match: future 0.16.0
# Adding future 0.16.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for pommerman==0.2.0
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Collecting git+https://github.com/openai/gym
#   Cloning https://github.com/openai/gym to /tmp/pip-req-build-i9sjsfru
# Requirement already satisfied (use --upgrade to upgrade): gym==0.10.9 from git+https://github.com/openai/gym in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.14.6)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.11.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (1.22)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym==0.10.9) (0.16.0)
# Building wheels for collected packages: gym
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-prink2x9/wheels/d5/72/8b/930cb346bdca1819ddcfc8f0325276ea09c92c3005f6c51a54
# Successfully built gym

# %%
#Check if gym library has been imported successfully
try: 
  import gym
  # !pom_battle
except ImportError:
    #In case of error reinitiate the enviorment (check Note at the beginning)
    print("Please restart and run all.")
# Out:
# Import error NSDE! You will not be able to render --> Cannot connect to "None"
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Starting the Game.
# Final Result:  {'result': <Result.Win: 0>, 'winners': [3]}
# Game Time:  2.304126739501953

# %% [markdown]
# # CODE
#
# Code developed to train Pommerman agents.

# %%
# Import more needed libraries
from pommerman.agents import SimpleAgent, RandomAgent, PlayerAgent, BaseAgent
from pommerman.configs import ffa_v0_fast_env
from pommerman.envs.v0 import Pomme
from pommerman.characters import Bomber
from pommerman import utility

# %matplotlib inline
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.nn import Linear, GRU, Conv2d, Dropout, MaxPool2d, BatchNorm1d, BatchNorm2d
from torch.nn.functional import relu, elu, relu6, sigmoid, tanh, softmax
import copy


# Instantiate the environment
config = ffa_v0_fast_env()
env = Pomme(**config["env_kwargs"])

# CUDA
use_cuda = torch.cuda.is_available()

device = torch.device("cuda:0" if use_cuda else "cpu")
print("Using device:", device)
# Out:
# Import error NSDE! You will not be able to render --> Cannot connect to "None"
# Using device: cuda:0

# %%
class QNetwork(nn.Module):
    """Q-network class (Deep Q-Network implementation)"""
    """It contains all the structure described on the extended Model B"""

    def __init__(self, n_channels, n_outputs, learning_rate):
        super(QNetwork, self).__init__()
        
        # Conv layer
        self.conv_1 = Conv2d(in_channels=n_channels,
                             out_channels=64,
                             kernel_size=5,
                             stride=1,
                             padding=2)
        
        # Max pool layer
        self.pool_1 = MaxPool2d(kernel_size=3,
                                stride=2,
                                padding=0)
        
        # Conv layer
        self.conv_2 = Conv2d(in_channels=64,
                             out_channels=32,
                             kernel_size=5,
                             stride=1,
                             padding=2)
       
        # FFNN layer
        self.fc = nn.Linear(800, 650, bias=False)
        
        # Output layer
        self.out = nn.Linear(650, n_outputs, bias=False)
        
        self.dropout = Dropout(p=0.5)
        self.batchnorm1 = BatchNorm2d(64)
        self.batchnorm2 = BatchNorm2d(32)
        
        torch.nn.init.uniform_(self.out.weight, 0, 0.01)
        
        # SGD optimizer
        self.optimizer = optim.SGD(self.parameters(), lr=learning_rate)
        
    
    # Forward pass
    def forward(self, x):
        x = x.unsqueeze(0)
        x = self.conv_1(x)
        x = self.pool_1(x)
        x = self.batchnorm1(x)
        x = self.dropout(x)
        x = relu(x)
        
        x = self.conv_2(x)
        x = self.batchnorm2(x)
        x = self.dropout(x)
        x = relu(x)
        
        x = x.flatten()
        
        x = self.fc(x)
        x = relu(x)
        x = self.out(x)
        
        return x
      
    
    # Loss
    def loss(self, q_outputs, q_targets):
        return torch.sum(torch.pow(q_targets - q_outputs, 2))
    
    # Update q-target   
    def update_params(self, new_params, tau):
        params = self.state_dict()
        for k in params.keys():
            params[k] = (1-tau) * params[k] + tau * new_params[k]
        self.load_state_dict(params)

# %%
def one_hot(i, l):
    """One-hot encoder for groups of observations"""
    a = np.zeros((len(i), l))
    a[range(len(i)), i] = 1
    
    return a
  

def featurize(obs):
    """Define observations and prepares it for the next step"""
    
    # Different elements of the observation
    position = obs["position"]
    board = obs["board"]
    bomb_blast_strength = obs["bomb_blast_strength"]
    bomb_life = obs["bomb_life"]
    ammo = [obs["ammo"]]
    blast_strength = [obs["blast_strength"]]
    can_kick =[obs["can_kick"]]
    actionlist = obs['actionlist']
    
    teammate = obs["teammate"]
    if teammate is not None:
        teammate = teammate.value
    else:
        teammate = -1
    teammate = [teammate]

    enemies = obs["enemies"]
    enemies = [e.value for e in enemies]
    if len(enemies) < 3:
        enemies = enemies + [-1]*(3 - len(enemies))
    enemies = enemies
    
    #Array of observations prepared for the next step
    output = np.array([board, bomb_blast_strength, bomb_life])
    return output

# %%
class OwnAgent(BaseAgent):
    """Implementation of our own agent, based on Model B"""
    #Constructor
    def __init__(self, character=Bomber):
        self._character = character
        #Number of channels
        self.n_channels = 3
        #Dimension of the output layer
        self.n_outputs = 6
        #Learning rate
        self.learning_rate = 0.0005
        #Discount rate
        self.gamma = 0.99 
        #Action list
        self.actionlist = [6,6,6,6,6,6,6,6,6,6]
        #Target tau
        self.tau = 0.01
        
        #Q-network
        self.qnet = QNetwork(self.n_channels, self.n_outputs, self.learning_rate)
        #Target Q-network
        self.target_qnet = QNetwork(self.n_channels, self.n_outputs, self.learning_rate)
        self.target_qnet.load_state_dict(self.qnet.state_dict())
        # GPU
        if use_cuda:
          self.qnet.cuda()
          self.target_qnet.cuda()
        
        self.Q = 0
        self.Q1 = 0
    
    # Act function
    def act(self, obs, action_space):
        
        obs['actionlist'] = self.actionlist
        # 1- do foward pass of current state to compute Q-values for all actions
        self.qnet.optimizer.zero_grad()
        self.Q = self.qnet(torch.from_numpy(featurize(obs)).float().to(device))
        
        # 2- select action with epsilon-greedy strategy
        if np.random.rand() > epsilon:
          a = self.Q.argmax().item()  
        else:
          a = env.action_space.sample()
          
        # Save action chosen
        self.actionlist.insert(0,a)
        del self.actionlist[10]
        return a
    
    # After step function
    def afterstep(self, s1, r, a):
        s1['actionlist'] = self.actionlist
        # 3- do forward pass for the next state
        with torch.no_grad():
            self.Q1 = self.target_qnet(torch.from_numpy(featurize(s1)).float().to(device))

        # 4- set Q-target
        q_target = self.Q.clone()
        #Update value of the current action
        q_target[a] = r + self.gamma * self.Q1.max().item() * (not done)

        # 5- update network weights
        loss = self.qnet.loss(self.Q, q_target)
        loss.backward(retain_graph=True)
        self.qnet.optimizer.step()
        self.target_qnet.update_params(self.qnet.state_dict(), self.tau)

        return loss

# %%
# Pommerman agents setup
# Own agent ready to play against 3 simple agents
agents = {}

agent_id=0; agents[agent_id] = SimpleAgent(config["agent"](agent_id, config["game_type"]))
agent_id=1; agents[agent_id] = SimpleAgent(config["agent"](agent_id, config["game_type"]))  
agent_id=2; agents[agent_id] = SimpleAgent(config["agent"](agent_id, config["game_type"])) 
agent_id=3; agents[agent_id] = OwnAgent(config["agent"](agent_id, config["game_type"]))

env.set_agents(list(agents.values()))
env.set_init_game_state(None)

# %%
class RewardsShaper:
    """Implementation of our defined reward shapping"""
    def __init__(self):
        self.bomb_list = {'own_bombs':{},'other_bombs':{}}
        

    def run(self, s, a, s1, done, info):
        reward = 0
        lookup = ['Stop', 'Up', 'Down', 'Left', 'Right', 'Bomb']
        
        a = a[3]
        
        p  = s[3]['position']
        p1 = s1[3]['position']
        o1 = s[0]['position']
        o2 = s[1]['position']
        o3 = s[2]['position']
        
        # Update bomb_list
        if(a == 5 and s1[3]['bomb_life'][ p[0] ][ p[1] ] == 9):
          
          self.bomb_list['own_bombs'][str(p[0])+","+str(p[1])] = {
              'position': [ p[0], p[1] ],
              'strength': s[3]['blast_strength']
          }

        suicide = False;
        killer = 0
        chopTree = 0
        
        # Check if own bomb goes off
        for key, value in self.bomb_list['own_bombs'].items():
          b = (value['position'][0], value['position'][1])
          if(s[3]['bomb_life'][ b[0] ][ b[1] ] == 1): # Own bombs goes off at bomb_life = 1
            
            fire_list = []
            blast_strength = self.bomb_list['own_bombs'][key]['strength']
            
            fire_list.append(b)
            for i in range(1,blast_strength):  
              if (b[0] - i >= 0):
                if (s1[3]['board'][ b[0]-i ][ b[1] ] == 4):
                    fire_list.append( (b[0]-i, b[1]) )
              
              if ( b[0] + i < 11):
                if (s1[3]['board'][ b[0]+i ][ b[1] ] == 4):
                    fire_list.append( (b[0]+i, b[1]) )
              
              if (b[1] - i >= 0):
                if (s1[3]['board'][ b[0] ][ b[1]-i ] == 4):
                    fire_list.append( (b[0], b[1]-i) )
              
              if (b[1] + i < 11):
                if (s1[3]['board'][ b[0] ][ b[1]+i ] == 4):
                    fire_list.append( (b[0], b[1]+i) )
            
                                 
            del self.bomb_list['own_bombs'][key]
            
            if(p1 in fire_list):
                suicide = True
            
            if(o1 in fire_list):
              killer += 1
              
            if(o2 in fire_list):
              killer += 1
              
            if(o3 in fire_list):
              killer += 1
            
            
            for pos in fire_list:
              if(s[3]['board'][pos] == 2):
                chopTree += 1
                
            break

        # Reward: Lay bombs and have ammo
        if(a == 5 and s[3]["ammo"]>0):
            reward += 0.1
            
        # Penalty: Lay bombs and have no ammo
        elif(a == 5 and s[3]["ammo"]==0):
            reward -= 0.1

        # Penalty: Go into fire! or stone, wood or off the board
        y, x = s[3]["position"]

        if(a==3): # action is go left
          if(p[1]-1>=0): # is on the board
            next_pos = s[3]['board'][ p[0] ][ p[1]-1 ]
            if(next_pos == 4): # fire
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # on not the board
            reward -= 0.1

        elif(a==4): # action is go right
          if(p[1]+1<11): # is on the board
            next_pos = s[3]['board'][ p[0] ][ p[1]+1 ]
            if(next_pos == 4): # and fire to the right
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # not the board
            reward -= 0.1
            
        elif(a==2): # action is go down
          if(p[0]-1>=0): # is on the board
            next_pos = s[3]['board'][ p[0]-1 ][ p[1] ]
            if(next_pos == 4): # and fire under
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # not the board
            reward -= 0.1

        elif(a==1): # action is go up
          if(p[0]+1<11): # is on the board
            next_pos = s[3]['board'][ p[0]+1 ][ p[1] ]
            if(next_pos == 4): # and fire over
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # not the board
            reward -= 0.1

        # Penalty: Don't stand still for more than 10 turns
        index = 0
        counter = 0
        for i in range(len(ep_actions)):
          counter+=1
          if(ep_actions[-counter])!=0:
            counter-=1
            break
        
        if(counter>9):
          reward += (9-counter)
          
        # reward: picking up powerups!
        powerup = 0
        if (s1[3]['blast_strength'] > s[3]['blast_strength']):## incr range
          powerup += 1
          
        if (s[3]['board'][ p1 ] == 6): ## extra bomb
          powerup += 1
        
        if (s[3]['can_kick'] == False and s1[3]['can_kick'] == True):  ## can kick
          powerup += 1
        
        
        reward += 4*powerup
        reward += -3*suicide
        reward += 10*killer
        reward += 2*chopTree
        
        return reward, suicide

# %% [markdown]
# # START TRAINING

# %%
# train Q-network
# %%time

env.seed(0)

num_episodes = 50000
episode_limit = 1000
val_freq = 100 # validation frequency

try:
    epsilon = 1.0
    shapedreward = RewardsShaper()
    rewards, lengths, losses, epsilons, wins, actionlog = [], [], [], [], [], []
    print('start training')
    for i in range(num_episodes):
        # Init new episode
        s, ep_reward, ep_loss, suicide, ep_actions = env.reset(), 0, 0, 0, []
        q_values = []
        r = 0
        
        # Maximum rounds per episode
        for j in range(episode_limit):
            actions = env.act(s)
            s1, r, done, info = env.step(actions)
            
            #Check if our agent is still alive
            if(13 in s[3]['alive']):
                ep_actions.append(actions[3])
                
                shaped, suicide = shapedreward.run(s, actions, s1, done, info)
                ep_reward += shaped
                r[3] += shaped
                loss = agents[3].afterstep(s1[3], r[3], actions[3])

                ep_loss += loss.item()
                q_values.append(agents[3].Q)
            else:
              done = True
               
            s = copy.deepcopy(s1)
            if done: break
              
        # Episode is finished
        if(suicide>0):
          print("s",end="")
          wins.append(0)
        elif("winners" in info):
          if(3 in info["winners"]):
            ep_reward += 1
            wins.append(1)
            print("W",end="")
          else:
            ep_reward -= 1
            wins.append(0)
            print(".",end="")
        else:
            ep_reward -= 1
            wins.append(0)
            print(".",end="")
        
        # Bookkeeping
        epsilon *= num_episodes/(i/(num_episodes/20)+num_episodes) # decrease epsilon
        epsilons.append(epsilon); rewards.append(ep_reward); lengths.append(len(ep_actions))
        losses.append(ep_loss); actionlog.append(ep_actions)
        if (i+1) % val_freq == 0: print('{:5d} mean training reward: {:5.2f}'.format(i+1, np.mean(rewards[-val_freq:])))
    print('done')
except KeyboardInterrupt:
    print('interrupt')
# Out:
# start training
# s.sss.ssssssssssssssss.sssssssssssss.ssss.sssssssss.sss..s.sss.sssssssssssssssssss.sss.ssss.sssss.ss  100 mean training reward: -1.46
# s.sss.ssss..sssssss.ssssss..ss..ssssssssssss..s.s.sss.ss..sss.ssss.ssssssssss.ss.ssss.ssssss.sssssss  200 mean training reward: -1.40
# sssss..ssssssssssssss.s.ss.s.sssssssss.ssss.ssssssssssssss.sss..sssssssssssss.ssssssssssss..s.ssssss  300 mean training reward: -1.70
# ss.ss.s.sss.sss.sssssssssssss.sssssssssssss.sss.ss..ssss.sssssss.ssssssss..sssssss.s.ss.ss.ss.sssss.  400 mean training reward: -1.43
# sssss..sssssssss.sss.sss.ssssssssssss.ssss.sssssss.ssssssssss..s.s.sssssssssss.ssss.sssssssssssss.ss  500 mean training reward: -0.74
# sssssssss.sssssss.ss.s.sss.ssssssssssssssssssss.ss.s.sssssssss.sss.ss.sss.s.sssssssssssss..s.sssssss  600 mean training reward: -1.00
# ssssssss.s.sssss.ssss..sssssssssssssss.ssss..ssssssssss.sss.ssssssss.ssssss.sssss.sssss.ssssssssssss  700 mean training reward: -1.31
# ..ssssssssss....ssss.sssssssssssssssssssss.s..s.sssss.sssssssss.s.s.sss.sssssss.ssss.ss.ssssssss.sss  800 mean training reward: -1.51
# sssssss.sss...ss.ssssss.ssss.sssss.ssss.s.ssss..s.ssssssssssssssssssss.sss.sssssssssssss.ssssssssss.  900 mean training reward: -1.16
# ssss.sssssssss..ssss.ss.s.ss.s.ssss..sssss.ssssssssss.ss..ssssssss..ssss.sssss...ssss.ssssss.ss.ssss 1000 mean training reward: -0.99
# ssss.ss.sssssss.sssss.sss.ss.sssssss.s.ss.sssss.sssssss..sssss.sssss.ssss..sssssssss.s.ssssss..ss.ss 1100 mean training reward: -1.39
# sssss.ssssss..ssss.sssssss.sssssss.sss..ssssssssss.ss..ssssss.sssss.ss.sssss.ssssssssss.ssssssssssss 1200 mean training reward: -1.33
# ssss..sssssssssss.sssssssssss.sssssss..s....ss.s.sssssssss.sssssssssssss.ssss.ssss.s...s.s.sss.sss.s 1300 mean training reward: -1.41
# s..ss.ss.ssssssssss..ss.ssssssss.sss.sssssssssssss.ssssssssss.sssssss.sssssss.sssssss.ssssss.ssss.ss 1400 mean training reward: -1.16
# sss.ss.ssssssssss.sss.sssssss.s..s..sssssssssssss.sss.ssssss.ssss.ss..sss.ssssssssssssss..s.ssssssss 1500 mean training reward: -0.91
# sss.ssss.sssssssssssssss.ss.s.s.ssssssssss.ss.ssss.s.sssssssssss.ssss.sssss.ss..ss.ssssssss.sssssss. 1600 mean training reward: -1.20
# ssssssssss.s.s.ss.sss.ssss.sssssssssssssssssss.s.ssssss..s..sss.sssssssss.sss.ssss.ssss.sss..s.sssss 1700 mean training reward: -1.15
# s...ssss.s.s.ssssssssssss.ss..sss.sssssss.s.ssss.sssss.sssss..ss..sssssssssssssssssssss..ss.ss.ssss. 1800 mean training reward: -1.20
# ssssssss.sssssssssss..ss.s..sssss.s....ss.ssss.ssssssssssssssssssss.s.sss.sss..s.ss.sss.ssssss..s.ss 1900 mean training reward: -0.68
# s...ss.sss.sss.sssss.ss.ssssssssssssssssss.ssssss..ss..sssss.ssssssssssssssss.sssss.s.sssss.ssssssss 2000 mean training reward: -0.57
# sssssss.s.ssss.ssssssssssssss.s.ssssss.sss.s..sssss.sssssssssss.sss..s.sssssssss.sssssssssssssssssss 2100 mean training reward: -1.51
# s..s.ssssss..sssss.ssssssssss...sssssssssssss.sss.ssssssssss...ssss.sssssss.sssss.ssssss.ssssssss.ss 2200 mean training reward: -1.00
# .s..sssss.ss.ssssssssssssss.ss.ssssss.sssssssssss..ssssssssss.ss.sssss.sss.sssssss.ss...ssssssssssss 2300 mean training reward: -0.92
# ssss.ssssss.ssssss.s.ssssssssssssssss.sssssss.ssssss.s.sssssssss.sss.ssssssssssssssss.ss.s.sssssss.s 2400 mean training reward: -1.62
# sssss.ssssss.s.sss..sssss.ss.ssss.sssssssssssssss.ssssssssssss.ssss..ss.sssss.s.ssss.ss..sss.sssssss 2500 mean training reward: -0.96
# ssss..sssssssssssssssss.ssssssssssssssss.ssssssssssss..ssssss..s.sssss.ssss.sss.ssssssssssssss.sssss 2600 mean training reward: -1.04
# .ssss.sssss.sssss.sss..ssssss.s.ssssssssssss.ssssss.sss..ss.ssssssssssssssssssssssss.sssssssssssssss 2700 mean training reward: -1.35
# sss.ss.ss.sssss.ssssssssss.ssss.sssssss.sssss.sssss.sssssssssssssssss.sssss.sss.ssssss.s...sssssssss 2800 mean training reward: -1.28
# sss.ss.sss.sssssss.sss.sssss.ss.sssssss.ssss.ssss.sssss.sss.sssssssssssssssssssss.sssssss.ssssssssss 2900 mean training reward: -1.68
# .sss.sssss.s.sssssssssss....s.sssssssssssssssss.sssssss.sss.s.s.ss...ss..sss..ssss.ssssssssssssss.ss 3000 mean training reward: -1.25
# sss.sssssssssssssss.sss..sssssssssssss.sssssssssssssssssssssss.s.sssss.ss.sss.sssss.sssssssss.ssssss 3100 mean training reward: -1.58
# s.ssssssssssss.ssssss.ssssss.ssssssss.sssssssssss.s.sss.s.ssssssss.ssss...sssssssssssssss.ssssssssss 3200 mean training reward: -1.19
# sssssssss.sssssssss.sssss.ssssss.ssssss..ssss.sssssssss.ssss.sssssss.sssssssssssssss.sssssssssssssss 3300 mean training reward: -1.47
# sssss.s.ss.ssssssssssssssssss.ss.s.sss..sssssssssssss.ssss.sss..sssssssssss.s.ssssssssssssssssssssss 3400 mean training reward: -1.02
# sssss.s.sssssssssssssssssss...ssssss.sss..sss.ssss..ssssssss.ssss.ss.sssss..sssss.ssss.ss.ss.ssssss. 3500 mean training reward: -1.41
# s.s.sssssssss.ssssssss.ssssssss.ss..ss.s..sssss..sss..sssss..sssssss.sss...ss.sssssss.ssssss.s.s..ss 3600 mean training reward: -1.51
# s.sss.ss.ssssss.s.ssssssssssssssssssssssssssssssssssssssssss.ssss..ss.s.ssss.s.ss.sss.ss...ss.ssss.s 3700 mean training reward: -1.31
# s.sssss..sssssssss.sssssssssssssss.ssss.sss.sssss.s.ssssss.sssss.sssssss.ssssss.s.s..sssss.ssss.ssss 3800 mean training reward: -0.80
# ss.sssss.sssss.sss.sss.sss.s..sss.sss.s.sss.ssssssssssssss.s..sss.sssssss.s.s.s.ss.s.sss.ss.ssssssss 3900 mean training reward: -1.09
# sssssss.ss..sssssssssss.sssss.sssss..s..s.s....s.ssss.ssssssssssss..s.ssss.ssssss.ss.s.sssss.sssssss 4000 mean training reward: -1.22
# s.ss.ss.ss.ss.s...ss..ssssssss.ssssssss.s.sssssssss..s.ssssssssssssssssss.ssssss.sss.ssss.sssssss.s. 4100 mean training reward: -1.42
# sssssssssssssssssssss.sssssssssssssssss...ssssss.ssss.ss.ssssssssssssss.sssss.sssss..ssssssss..sss.s 4200 mean training reward: -1.26
# ssssss.ss.s.ss.sssss..s.sssssssssssssss..sss.sssssss.sss.s.ssssssssss.ss.sssssss.sss..sssssss..ssss. 4300 mean training reward: -1.57
# sssssss.s.sss.ssss.ssssss.ss.ss.sss..s.s.sssss.s.sssssssssssss....sssss..sssssssssssss.ss.sss..sss.s 4400 mean training reward: -1.35
# ss.ssss.sss.ssssssss.s...ss.sssss.ss..ssss.ssssssss.s.ssssssssssssssssssssssssss...sss.ssssss.ss.sss 4500 mean training reward: -0.84
# ssssssssss.sssss.sss..sssssssss.s..ss.ssss.sss.s.sss.ss.s..sss.sssss.s.ss.s.ssssssss.ssss.ssss.sssss 4600 mean training reward: -0.82
# .sss.s..sssssssssssssssssssssss.ssssss...sss..ssssssssssssssssss.s.ssssss.sss...ss.s.sss.sss.sssssss 4700 mean training reward: -1.24
# .ss.ss.sssss.s.sssssssssssssssss.ssssss.ssssssss.ssss.ss.ssssssss..ssssssssssss.ssssssssss..s.ssssss 4800 mean training reward: -1.44
# s.sss..sss.ssssssssssssssssssssssss.ssssssss..sss.ssssss..ssssssss.s.sssss.sssss.sssssss.ssssssss.ss 4900 mean training reward: -1.34
# s.ss.sssssssssssssssssss.sssssssss.sss.sss.ssss.sss.sss.sssssssss.sssssss.sssssss.ssssssssss.sssssss 5000 mean training reward: -1.11
# s.ssssssss.sssssss.ss.ssssssssss.sssss.s.ssssss.sss.sssss.sssssss.s.sssss..ssssss..ssss.sssssssss.ss 5100 mean training reward: -1.39
# ssss...ssssssssssssssss.ssss..ssssssssssssssss.sss.sss.s.ssssssssssss..ssssssss..s.sss.sss.ssssssss. 5200 mean training reward: -1.11
# ssss.ss..sss.sss..sss.ssssssssssss.s.ss.s.sss.s.sss.ss..sssssss.sssssss..s.s.sssss.ssssss.s.s.ssssss 5300 mean training reward: -0.91
# ssssssssss.sssssss.ssssss.sssssssss.ssssss.ssssssssssssssss.ssss.ssssssssssssssssssssss.ssssss.s.sss 5400 mean training reward: -1.45
# ssssss.s.sssss.sssssss..s.sss.sss.ssss.sssssssss.ss.sss.ssssssssssss.ssss.s.ssss.sss..ssssssssssss.. 5500 mean training reward: -1.23
# sssssssssssssssssssss.ss.s.ss..ss.sssssssssss.ss.s.sssssss.ssssssssss...sssssss.sssssssssssss.s.ssss 5600 mean training reward: -0.70
# .sss.s.sssssss.ssssssssssssssssssssssss..ssssssss.ssssssssss.ss.s.sssss.ss.sss.ssssssssssssssssss.ss 5700 mean training reward: -0.78
# .ss.sssssssssssssssssssssssssss..ssss.ssss.ssssss.ss..sssssss....sss.s.sssss.sssssss.ss..sssssssssss 5800 mean training reward: -1.56
# ssssssssss.sss..ss.sssssssssss.sss.ss.sssssssssssssss...s.sss.sssss.s...ssssss.sss.s.sssssss.sss.sss 5900 mean training reward: -0.85
# .sss..ss.sssssssss.sss.ss.ssssssss.sssssss.ss..sssss.ssssssssssssssssssssssssssss.ssssssssssssssssss 6000 mean training reward: -1.64
# sssss.ssssssssssssssssssssssssss.ss.sssssssssssssssss.ssssssssss.sss.sss.sssssss..ssssss.s...s..ssss 6100 mean training reward: -1.28
# sssssss..sssssssss.sssss..ssssssssssssssssssssssssssssssss....sssss.sss.ssssss.s.sssssssss..s.ssssss 6200 mean training reward: -1.19
# s..sssss.sss.sssss.ssssssssssssss.sss.ssss..ssss..s.s.sssssss.s.ssssss.sss.s.ssssssss.s.sss.sssss.ss 6300 mean training reward: -0.99
# sssss.sssssssssssssssssssssssssssssss.sssss..ss.ss..ssssss.s.ssssssssss.ssss.ssssssssss.sss.sssss..s 6400 mean training reward: -1.20
# ssssss..s.ssssssss.sssssssssssss.ssssss.sssss.sss.s.sss.sssss.ssssssssssssss.ssssssss.ss.sss.sssssss 6500 mean training reward: -1.14
# sssssss.sssssssssssssssss.sss..ssss..sssssss.ssss.sssssssss.s.s..ss.ssssssss.s.s.sss.sssss.ss.ssssss 6600 mean training reward: -1.10
# sssssssssssssssssssssssssssssss..sssss.s.ssssssssssssssssss.sss..ssssss.ssssssssssssssssssssssssssss 6700 mean training reward: -1.56
# .sssssssssssssssssssssss.ssssss.ssss.sss.ssss.ssss.sssss.ss.sssssss..sssssssss.sss.s.ssssss.ssssss.. 6800 mean training reward: -1.06
# ssssssssssssssss.sss.sssssssssssss.sssssssss.ssss..sssss.sssssssssssss.s.sssssss.sss..ssssssssssssss 6900 mean training reward: -1.20
# sssssssss.sssssssssss..ssssss.sssss.ssssssssssss.ss.ssssss.ss.sssss.ssssssssssss..s..sss..ssss.sssss 7000 mean training reward: -1.44
# sssssssssss.ss.ssssssssssss.sssssssssssssss.ssssss.sss.s.s.sssssssssssssssssss.ssssssss.ss.ss.ssssss 7100 mean training reward: -0.99
# ssssss.sssss.s.ss.s..sss.ssss.s.sssss.sss..sssssssssssssssssssss.sssssssssss.sssssssssssssssss.sssss 7200 mean training reward: -1.47
# ssssssssss.sssssssss..ssssssss.sss...sssssssss.ssssss.sss.s.ssssssssssssssss.ssss.s..ssssssss..sss.s 7300 mean training reward: -1.35
# ssssssss.sssssssss.sss.sss.ssss.sssss..sssss..ssssssssssssss.sss.ssssssssssssssssss.sss.s..sssssssss 7400 mean training reward: -1.50
# s.sss..s..ss.ssssssss.sss.ssssssssssssssssss.ssss.sssssssssssssss.s..sssssssssssssssssssssssssssss.s 7500 mean training reward: -1.43
# ss.sss.ssssssssss...ssssssssssss.sssssssssss.sssss.s.ssss..sss..s.sssssssssssssssssssssssssssssssss. 7600 mean training reward: -0.97
# sssssssssssssssss.ss.ssss.ssss..sss..ssss.sss.ssssssssss.ss.s.sssss.sss.ssssssssssss..sss.sss..s.s.. 7700 mean training reward: -1.01
# s.sssssssss.ss.ss.s..ss.ssssssssss.s.ss.ss.ssss.ss.sssss.sss..sss.s.ss.ssssssss.s.sssssss.ssssss.sss 7800 mean training reward: -1.06
# ss.sssss..s.ssssss.s.sssss.s.ss.sss.s.ssss.s.ss.ss.ss.sssss.sss.sssssssssssssss.sssss..s.sssss..ssss 7900 mean training reward: -0.88
# sssssssssssssss.ssssss.sss.ss.sssssssssssssssssssss.sssssssssssssssssssss.sssssssss.ssssssssssss.sss 8000 mean training reward: -1.56
# ssssssssssssssssssssssss..ss..ssss.s.s..sssssssss.sssssssssss.ssssss.ssssss.s.ssss.ss.sssssss...ssss 8100 mean training reward: -1.26
# ssssssssss.sss.ssssss.sssss.s.s.ss.ss.sssss.ss.ssssss.sss.ssss.ssssss.sssss.sssssssssss.s..sss..ssss 8200 mean training reward: -1.10
# sssssssss.ssssssss.ssss.sss.sss.ss.s.ss.ss.sssssssssssssssssssss.ssssssssssssss.ssssss.sssss.sssssss 8300 mean training reward: -1.25
# sssssssssssss.ss.sss.ssssssssssssssss.ss.ssssss.ss...ssss.ssssssssssssss.ss.ssss.sssss.ssss.ssssssss 8400 mean training reward: -1.13
# ss.ssssss...ssssssssssssssssssss..sss.ssss.sssssssssssssss..sssssssssssssss.sssss..s...ssssssssssss. 8500 mean training reward: -1.06
# ssssssss.ss.ssss.ss.sss..sssssssssssss..ssss.sss..s.ssss.sssssssssssssssssssssssssssssssssss.sss.ss. 8600 mean training reward: -1.32
# ssssssssssss.ssssssss.ssssssssssss.ss.s.sss.ss..ssssssssssss.ssssssssssss.sssssssss.sssssssss.ss..ss 8700 mean training reward: -1.61
# ssss.sssssssss...s.s.ssss.ssss.ss.ss.ssss.ssss...ss.sss.ssss.sssssss.sss.ssssssss.ssssss.sssssssssss 8800 mean training reward: -1.13
# ssssss.sssss.ssssssssss.sssssss...s..sss.sssssssssss.sssssssssssss.ss.sss.ss.ssssssssss.ssssssssssss 8900 mean training reward: -1.57
# ssssssssssss..sssssss.sssssssssssss..ssss.sssssssss..sssssssssssssssssss.ssssssssss.ssssssssssssssss 9000 mean training reward: -1.42
# sss..sssssssssss.sss.ssssssssssss..ss.sss..ssss..ss.sssssss.sssssss.ssssssssssss.sss.s.sssssssssss.s 9100 mean training reward: -1.43
# s..ssss.sssssssssssssssssssssssssss.ss.....ssssss.ss.ssss..sssssssssss.s.ssssssssssss.sssss.ssssssss 9200 mean training reward: -1.37
# .sssssssssssss.ssssss.ssssssss.ssss.sssssssssssssss.ssssssssssssssssssssss.sss.sssssssss.ssssssss... 9300 mean training reward: -1.00
# sssssssssss.sssssssssssssssss.ssss.ssssssssssssssss.ssss.sssssssss.sssssssssssssssssssss..ssssssssss 9400 mean training reward: -1.09
# ssssssss.ssssssss.ssssssssssss.sssssssssssssssss.s.ssssssssssss.s.sssssssssssssss.ssssssss.s..ss.sss 9500 mean training reward: -1.37
# ssss.ssssssssssss.s.s.sssss.ssssssss..ss.s.s.sssssssss.ssssssssssssssssssssssssssss.ssssssss.sssssss 9600 mean training reward: -1.31
# sssss.ss.sssssssssssss.ssssssssssss.ssssssssss.sssss.sssssssss.ssssssssss..sssssss.sssssss..sss.ssss 9700 mean training reward: -1.15
# .s.ssss.ssssss.sssssss.ss.sssssssssssssss.ss.ss.sssssss.s.ss.s.ssssssssssss..ssss.sss...s...ss.ss.ss 9800 mean training reward: -0.92
# s.ssssss.sss.ssssss.sssssssssss.s..ssssssss.ssssssssssss.ss.ss.sssssssssssssss.sss.ssssssssssss.sss. 9900 mean training reward: -1.26
# ss.sssssssss.sssssssssss.ssssssssss..sssssssss.ssssssss.s.s.ssss.ssss.s.sss.s..ssssssssssssss.s.ssss10000 mean training reward: -1.00
# ssssss.ssssssssssssssssss.sss.ssssss.sssss.ssssss.ssssssss..ssssssssssssssssssssss.sssss.s.sssssssss10100 mean training reward: -1.43
# ssssss.sssssssss.sssss.ssssssssss.s.s.sssssssssssssssss.s.sssss.ssss.sssssss..ss.ssssssssssss.ssssss10200 mean training reward: -1.81
# ssssss.ssssss.ssss..ssssssssssss.ssss.ssssssssss.sssssssss.ss.ssss.sssssss.ssssssssss..s.ssss.s..s.s10300 mean training reward: -1.23
# .s.ss.ssssss.ssssssssss.s.ssss.ssss.sssss.ss.ssssssssssssss.ssssss.ss.sss.sssss.ssssssssssssssss.sss10400 mean training reward: -1.21
# ss.ssssssssssssssssssssssssssss.ssss.sssssss.sssssss.ssssss.ssssssssss.sssssssssssss.sssssss..s.ss.s10500 mean training reward: -1.56
# ssssssssss.sssssssssss.sssssssssss.ssssssssss..ssssssss.s.ssssssss.s..ssss.ssssssssssssssss.ssssssss10600 mean training reward: -1.61
# sssssssssss.ssss.ss.ss.sss.sssssss.Wssssss...s.ss..ss.s..ssss.ssss.ss.sss.ssss.sss.sssssss.ssssssss.10700 mean training reward: -1.27
# .ssss.sssssssssssss.sssss.ssss.ssssss.ssssssssss..ssssss..s.s.ssss.ssssssssssssssss.s.sssssssss.ssss10800 mean training reward: -1.35
# sss.ssss.ss.s.s.sssssssss.s..sssssss..sssss.ssssssss.sssssss.s.ssss.ssssssssssssssss.sssWssssss.ssss10900 mean training reward: -1.61
# ssss..sssssssssssss.ss.sssssssss.s.ssssss.ssssssssssssssssss.ssssssssss.ssss.ssssssssss.ssssssssssss11000 mean training reward: -1.41
# ss.s.ssssss..ssssssssssssss.ss.sss.s.ssssss.s..ssss.sssssssssssssssssssss.sssssss.sssss.s.sssss..sss11100 mean training reward: -1.33
# ssssssss.ss.s.ssssss.s.sssssssssssssss.ss.sssssss.s.s.ssss.ssssssssssssss.ssssssssssssssss.sssssssss11200 mean training reward: -1.53
# sssss.s.sssss.s.sssssssss..sss..sss.ssssssssssssssss.sss.sssss.ss.sssssssss.ssssss.ssss.ssssssssss.s11300 mean training reward: -1.31
# sssssssssssss.ss...ss.sssssssss.ssss.s.sss.ssssss.ss.sssss.sssssss.sssssssssssssssss.sssssss.ss..sss11400 mean training reward: -1.61
# s.sssssssssssssssssssssssssssssss.ssssssssssssssssss.sss.ssss.ssssssssssssssssssss..ss.sss.sssssss.s11500 mean training reward: -0.85
# ss.ssssssss.sssssssssssss.sssssssss.s.s.ssss.s.sssss.sssssss.sssss.ss.ssssssss.ss.sssssss.sssss.sss.11600 mean training reward: -1.66
# sssss.ssssssssss.ssssssssssss.sss.s.s..sssssssssssssssss.ssssssss.ssssssssssss.sssssss.ss.ss.ss.s.ss11700 mean training reward: -1.50
# sss..sssssssssssssssssssssssssss.ssssss....sss..s.ss.ss.ss.ssssssssssssssssssss.ss.sssssssssssssssss11800 mean training reward: -1.53
# .sssssssss.ssssssssssssssss.ssssssssssssssssssss.ssssssssss.ssssss.s.s.sssssssssssssssss.sssss.sssss11900 mean training reward: -1.50
# s..ssssssssssssssss.ssssssssssss..ssssss.ss.ssssss.s.ssssssssssssssssss...sss..sssssssssssssss.sssss12000 mean training reward: -1.62
# sssssss.sssssssssss.sssssssssssss.sss.sssssssss.sss.sssssssssssss.s.sssssssssss..ss.ssssssssssssssss12100 mean training reward: -1.06
# ss.s.sssssssssssssssssssssssssssssssssss.ssssss.ssssssss..ssssssssssssssssssssss.sssssssssssss.ss.ss12200 mean training reward: -1.49
# sssssssss.s.ssssssss.ssssssssssssssssssssssssssss.ssssssssss.sssssss.sssssssssssss.sssssssssssssssss12300 mean training reward: -1.84
# ssssss..sssssssssss.sssssss.sssssss.s.ssssssss..sssss..ssssssssss.ssss.s.ssss.ssssssssssssssssssssss12400 mean training reward: -1.16
# ssss.sss.s.ssssss.s.s.ssssss..sssssssssssssss.ss.s.sssssssssssssss..sssssssss..ssssssss.sssss.ssss..12500 mean training reward: -1.46
# ssssssssssssssssssssssssss.sssssssssssssssssss.ss.s.sssssss.sss.ss.sssssss.ssssssssss.ssssssssssss.s12600 mean training reward: -1.37
# .sssssssss.ssssssssssssssssssss.ss.s.ssssssss.ssss.sssssssssssssssss..ssss.ssssssssssssssss.sssssss.12700 mean training reward: -1.70
# sssssss.ssssssss.s.sssssssssssssssssssssssssss.sssss.ssssssssssssssssssssssssssssssssssssssssssss.ss12800 mean training reward: -1.95
# sssssssss.sssssssssssssssssss.ss.ssssss.ssssss.sssssssssss.ssssss.sssssssssss.ss.sssssss.ssss.ssssss12900 mean training reward: -1.31
# ssssssssssssssss.ssssssssssssssssssssss.sssss.sssss.sssssssssssssss.sssssssss.ssssssss.ssss.ssssssss13000 mean training reward: -1.65
# sssssss.sssssss.sssssssss..sssssss.s.sss.s.s.ss..ssss..ssssssssssss.s.ssssssssssss.sssssssssssssssss13100 mean training reward: -1.71
# ssssssssssssssssssssss.s.ssssssss.ssssssssss.s.ssssssssssssss.sss.sssssssssssssssssssssssssssssssss.13200 mean training reward: -1.18
# s.sssssssssssssss.ssssssssssssssssssssssssss.ssssssssssssssss.ssssssssssssss.sssssssssssssss.sssssss13300 mean training reward: -1.45
# sssss.ssssss..ssssssssssssss.s.ssssssssss.sssss.sssssss.ssss.ssssssssssssssssssssssssss.ssssssss.sss13400 mean training reward: -1.35
# sssssssssssssssssssssssssssss.sss.sssssssssss.sssss..ssssssssss.ss.sssssss.sss.sssss..sssssssssss.ss13500 mean training reward: -1.74
# ss..ssssss.sss.sssssssssssss.ssssss.sssssss..sssss..s.ssssssssssss.sss.sssss.sssssssssss.s.sssssssss13600 mean training reward: -1.43
# sssssssssssssssssss.ssssssss.ss.ss.ssssssssssssss.sssssssssssssssssssssssssss.s.ssssss.s.sssssssssss13700 mean training reward: -1.58
# s.ssssss.ssssssssssssss.sssssssss.sssssssssssssssssss.ss.sss.sssssssss.sssssssssssssssssssssssssssss13800 mean training reward: -1.90
# .ssssssss.sss.sssssssssss.sssssssssssssssssss.sssssssss.ssssssssssssssss..ssssss.ssssssss.ssssssss.s13900 mean training reward: -1.44
# ssssssssssssssss.s.ss.ss.ss.s.ssss.sssssssssssssssssssssssss.sssss.ssssss.s.sssssssss.ssss.ss...ssss14000 mean training reward: -1.79
# ssssssssss.s.sssssssssssssssssssssss.sssssss.ssssssssssssssssssssss..s.sssssssssssss.sssssss.ssss..s14100 mean training reward: -1.71
# sss.sssssss.ssss.sss.ss.s.s..s.sssssssssssssssssssssssssss.ssssssss.s.sssssssssssssss.s.ssssssssssss14200 mean training reward: -2.04
# s.sssss.ssssssssssssssssssssssssssssss.sssssssssssss..ssssssssssssssss.sssssssssss.ssss.ssssssssssss14300 mean training reward: -1.59
# sssssssssssssss.ssss.sss.sssssssss.ss.ssssssssss..ss.ssssss.ssssssssssssssssssssssssss.ss.ssssssssss14400 mean training reward: -1.85
# sssssssssssss.s.sssssssssssssssssssssssssssssssssss.sssssss..sssssss.sssssssssssssssssssssssssssssss14500 mean training reward: -1.97
# sssssssssssss..ssssssssssssssssss.sssssssss.sssssssssss.ssssssss.sssss.ss.sssssss.sssssssss.sss.ssss14600 mean training reward: -1.94
# .sssssssssssssssssss.ssssssssssss.ssssssssssssssssssssssss.s.s.ssssss.sssssss.s..s.ssss.ssssssssssss14700 mean training reward: -1.61
# ssssssssssss.sss.ssss.ss.sssssssssssssss.s.ssssssssssssssssss.sss.sssssssssss.sssssssss.ss.ssss.ssss14800 mean training reward: -1.32
# ssssssssssssss.sssss.sssssssssssssssss..sssssssssssss.sssss.sssssss.ssssssss.sss.sss.sssssssssssssss14900 mean training reward: -1.52
# s.ssssssssssss..sss.sssssssssssss..ssssss.ssssss.ssssssssssssssssssss.ss.sssssssssssssssssssssssssss15000 mean training reward: -1.28
# ss..sssssssssssssssssssssssss.sss.ssssss.ssssssssssssss.sss.sssssssssssss.sssss.sss.sssssssss.ssssss15100 mean training reward: -1.37
# sssss..s.s.s.sss.ssss.ssssss..s.ssssssssssss..ssssssssssssssssssssssss.sssssssssssssss.sssssssssssss15200 mean training reward: -1.59
# sssssssssss.s.sssssssssss.ssssss.ssssssssssssssssssssss.ssssssss.ssssssssssssssssss......sssssssssss15300 mean training reward: -1.71
# ssssssssss.sssssss.ssssssssssssssssssss.sssssssssss.ssssssssss.sssssssssssssssssssssssssssssssssssss15400 mean training reward: -1.88
# ssssss.ssssssssssssssssssss.ssssssssss.sssssssssssssss.sssssssssssssssssssssssssssssssss.ss.ssssssss15500 mean training reward: -1.63
# sssssss..sssssssss.sssssssssssssssss.ssss.ssssssssss..ssssssss.s.ssssss..ssssssssssssssssssssss.ssss15600 mean training reward: -1.80
# ssssssssssssssssssssssssssssssssssssssssss.ssssssss.sss.sssssssssssssss.sssssssss.sssssssssssssss.ss15700 mean training reward: -1.75
# .sssss.sssssssssssssssssssssssssssssssss.sssssssss.sssssssssssssssss.ssssssssssss.sssssss.sssss.ssss15800 mean training reward: -1.41
# ssssssssssss.sssssss..sssssssssssssssssssssssssssssssssss.ssssssssss.sssssssssssssssss.sss.ssssss.ss15900 mean training reward: -1.60
# sssssssssssss.ssssssssssssssssssss.sssssss.ssssssss.sssssssss.ssssssssssssssssssssssssssssssssssss.s16000 mean training reward: -1.75
# sssss.ssssssssssssssssssssssssssss.ssssssssssssss.sssssss.sssssssssssssssssssssssssssssssssssssss.ss16100 mean training reward: -2.44
# sssssssssss.sssssssssssssssssssss.ssssss.ssss.sssss.ssssssssss.sssssss.ssssssssssssssssssssssss..sss16200 mean training reward: -1.39
# ssssss.sssssssss..s.sssssssssss.ssssssssssssssssssssssssssss.ss.ssssssssssssssssssssssssssssssssssss16300 mean training reward: -1.69
# ssssss.sssssssssss.ssssss.ss.sssssssssssssssss.sssssss.sssssssssssssssssssssssssssss.sssssssssssss.s16400 mean training reward: -1.77
# sssssssss.ssss.ssssssssssssssssssssss.ssssssss..sssssssssss.ssssssss.sssssssssssssssssssssssssssssss16500 mean training reward: -2.03
# sssssssss..ss.ssss.ss.ssss..s.sss.sssss.sssssssssssssssss.ss.ssss.ssssssssssssss.ssssssss.ssssssssss16600 mean training reward: -1.42
# sssssssssss.sssssssssssss.ssssssssssssssss.sss.ssssssssssssssssssssssssssssssss.ssssssssssssssssss.s16700 mean training reward: -2.43
# ssssssssssssssssss..ssssssssssssssssssssss.ss.ssssss.s.ssssssssssssss.sssssssssssssssssssssss.ssssss16800 mean training reward: -2.34
# ssssssssssssssssssssssssssssssssssssssss.ss.sssss.sssssssssssssssss.sssssssssss.ssssssssssssssss.sss16900 mean training reward: -1.81
# ssssss.s.ss.sssss.sssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssss.ssssssss.ssssssssss17000 mean training reward: -1.82
# ssssssssssssssssssss.sssssssssss.sss.sssssss.ssssssssssssss.ssssssssssssssssssssssssss.ssssssssssss.17100 mean training reward: -2.12
# ssssssssssssssssssssssssssss..s.ss.sssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssss.17200 mean training reward: -2.08
# ssssss.ssssssssssssssssssssssssssssssss.ssssssssssssssss.ssssssss.ssssssssssssssssss.sssssssssssss.s17300 mean training reward: -1.69
# ssssssssssss.sssssssssssss.sssssssssssssssssssssssssssssssssssssssss.ssssssssssssss.ssss.sssssssssss17400 mean training reward: -2.37
# ss.sss.ssssssss.ss.sssssssssssssssssssssssssssssssssss.ssssss.sssssssssssssssssssssss.ssssssssssssss17500 mean training reward: -2.21
# ssssssssssssssssssssssssss.ssssssssssssssss.ssssssssssss.s.sssssssss.sssssssssssssssssssssssssssssss17600 mean training reward: -1.91
# ssssssssssssssss.sssssss.s..sssssss.sssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssss17700 mean training reward: -2.46
# s.sssssssssssssssssssssss.sssssss.ss.s..ssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sss17800 mean training reward: -1.92
# sssssssssssssssssss.ss..sss.ssssssssssssssssss.ssssssssssssssssss.s.sssssssssss.sssssssssss.ssssssss17900 mean training reward: -1.44
# ssss.sssss.sssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.s.sssssssss18000 mean training reward: -1.81
# ssssssss..sssssssssssssssss.sssssss.ssss.ssssss.ssssssssssssssssssss.ssssssssssssssssssssss.sssss.ss18100 mean training reward: -2.49
# .ssssssssssssssssssssssssssssssssssssss.sssssssssssssssssssssss.ssssssssssssssssssssssss.sssssssssss18200 mean training reward: -1.72
# sssssssssssssss.sssssssss.ssssssssss.ssssssss.ssssssssss.sss.sssssssssssssssss.sssssssssssssssssssss18300 mean training reward: -2.05
# ssssssssssssss.sssssss.sssssssssssssssssssssss.sssssssssssssssssss.sssssssssssssssssssss.sssssssssss18400 mean training reward: -2.11
# ssssssssss.sss.ssssssssssss.sssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssss18500 mean training reward: -2.32
# sssssssssssssssssssssssssssssssssssssssssssssss.ss.s.sssssssssssss.ssssssss.ssssssssssssssssssssssss18600 mean training reward: -2.75
# sssssssssssssssssssssssssssssssssssssssssss.s.ssssssssssssss.ssssssssssssssss.sssss.ssssssssssssssss18700 mean training reward: -2.34
# sssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssss.ssssssssssssssssssssssss18800 mean training reward: -2.16
# sssssssssssssssssss.sssss.ssssssssssssssssssss.ssssssssssssssssssss.ssssssssss.sssssssssssssssssssss18900 mean training reward: -2.76
# ssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss19000 mean training reward: -2.22
# ss.sssssssssssssssssssssssssssssssssssssssssssssss.sssssssWssssssssssssssssssssssssssss..sssssssssss19100 mean training reward: -2.56
# ssssssssssssssss.ssssssssss.sssssssssssssssssssssssssssssssssssssssssssss.sssssssssss.ssssssssssssss19200 mean training reward: -2.04
# ssssssssssssssssssss.ssssssssssssssssssssss.ssssss.ssss.sssssssssssssssssss.sssssssssssss.sss.ssssss19300 mean training reward: -2.41
# s.ssssssssssss..sssss..Wsssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssss.ss19400 mean training reward: -2.40
# ssssssssssssssssssssssssssWsssssssssssssssssssssssssssssssssssssss.sss.sssssssssssssssssssssssssssss19500 mean training reward: -2.39
# ssssssssssssssss.sssssssssss.ssssssssssssssssss..sss.sssssssssssssss.sssssssss..ssssssssssssssssssss19600 mean training reward: -2.58
# sssssssssssssssssssssssssssssssssssssss.sssssss..sss..ss.sss.ssssssssssssssssssssss.ssssssssssssssss19700 mean training reward: -1.89
# ssss.sssss.ssssssssssssssssssssssssss.ssssssssssssssss.ssssss.sssssssssssss.sssssssssssssssssss.ssss19800 mean training reward: -2.76
# ssssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssss19900 mean training reward: -2.29
# .sssss.s.sssssssss.sssssssssssss..s..sssssssssssssssssssssssssssssssssss..ssssssssssss.sssss.ss..s.s20000 mean training reward: -2.31
# ssssss..s.sssssssssssssssssssssss.sssssssssssssssss.ssssssssssssssss.sssssssssssss.sssssssssssssssss20100 mean training reward: -2.94
# sss.ssssssssssssssssssss.s.s.sssssssssssssssssssssssssssssssssssssssssssssss.sssss.ssssss.ssss.ssss.20200 mean training reward: -2.41
# ssssssssssssss.ssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssss20300 mean training reward: -2.94
# sssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssss.sssssssssssss20400 mean training reward: -2.56
# sssssssssssssssss.ssss.ssssssssss.s..sssssssssss.sssssssssss.sssss.ssssssssssss.ssssssssssssssssssss20500 mean training reward: -2.72
# ssss.sssssssss.ss.sssssssssssssssssssssssssssss.sssssss..ss.ssssssssssssssssssssssssssss.sssssssssss20600 mean training reward: -2.46
# sssssssssssssssssssssssssWsssss.sssssssssssssssssssssssssssssssssssssssssssssssss.ssss.sssssssssssss20700 mean training reward: -2.62
# ssssss..ssss.ssssssss.ssssssssssssssssssssssss.ss.ssssssssss.ssssssssss.ss.sssss.sssssssssssssssss.s20800 mean training reward: -2.56
# ssssssssssssssssssssssssssssWsssssssssssss.s.sssssssss.sssss.sssssssssss.sssssssssssssssss.sssssssss20900 mean training reward: -3.23
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss21000 mean training reward: -2.77
# sssssssssssss..ssssssssss.sssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssss21100 mean training reward: -2.06
# sssssssssssssss.ss.sssssssssssssssssssssss.sssssssssssssssss.sssssssssssssssssssss.ssssssssWssssss.s21200 mean training reward: -2.06
# sss.ssssss.ss.sss.sssssssssssssssssssssssssssssssssssssssssss.sssssssss.ssssssssssssss.sssssssssssss21300 mean training reward: -2.44
# sssssssss.ssssssssssssss.s.ssssssssssssssssssssssssss.sssssssss.ssssssssss..ssssss.ssss.ssssssssssss21400 mean training reward: -3.36
# sssssssss.ssssss.sssssssssssss.ssssssssssssssss.sssssssssssssss.sssssssssssssss.ssssssssssssssssssss21500 mean training reward: -2.20
# ssssssssssssssssssssssssssssssssssssssssssssssssss.ss.sssssssssssssssssssssss.ssssssssssssssss.ssssW21600 mean training reward: -2.28
# ssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssssssssss.sssssssss.sssssssssssssssssssss21700 mean training reward: -2.43
# sss.ss.ssssssss.ssssssssssssssssss.sss.ssssssssssssssssssss.sssssss.ssss.sssssssssssssssssssssssssss21800 mean training reward: -3.23
# ss.s..ssssssssssssssss..sssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssss.ssssssssssss21900 mean training reward: -3.11
# sssssssssssssssssssssssssssssssssssssss.sss.ssssssssssssssssssss.sssss.ssssss..ssssssssssss.ssssssss22000 mean training reward: -3.32
# sssssssss.ssssssssssssssssssssss.ssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssss22100 mean training reward: -3.34
# sssss.ssssssssssssssss.s.sssssssssssssss.sssssssss..ssssssss.ssssssssssssssssssssssssssss.ssssssss.s22200 mean training reward: -3.53
# sssssssssssssssssssssssssssss.sss.sss.sssssssssssssss.sssssssssssssssssssssssssssssssssssssssss.ssss22300 mean training reward: -2.59
# sssssssssssssWsssssssssssssssss.s.ss.sssssssssssssssssssssssss.ssss.ssssssss.sssssssss.sssssssss.sss22400 mean training reward: -3.23
# sssssssssssssssssssss.sss.s.ss.ssssssssssssss.ssssssssssss.sssssss.sssssssssssssssssssssssssssssssss22500 mean training reward: -2.54
# sssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssss.sssss.ssssssssssss.22600 mean training reward: -2.20
# sssssssssssssssssss.ssssssssssssssssssss..sss.ssssssssssssssssssssssssssssssssssssssssssssssssssssss22700 mean training reward: -2.39
# sssssssssssssssssssss.s..ssssssssssssssssss..ssssss.sssssssssssssssssssssssss..sssssssss.s.sssssssss22800 mean training reward: -1.81
# ssssssssssss.sssssssssssssssssssssss.ssssssssssssssss.ssssssssssssssssss.sssssss.ssssssssssssssssss.22900 mean training reward: -1.53
# sss..sss..ss.sssssssssss.sssssssssssssssssssss.sssssssssssssssssssssssssss.sssssssssssssss.sssssssss23000 mean training reward: -1.52
# sssssss.ssss.s.ssssssssssss..sssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssss23100 mean training reward: -1.39
# sssssssssssssssssssss.sssssss.sssssssssssssssssssssssssssssssss.ssssssssssssssssss.sssssssssssssssss23200 mean training reward: -0.92
# sssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssss.s.ssssssssssssssssssss.s.ssss.sssssssss23300 mean training reward: -1.68
# sssssssssssssssssssssssss.s...sssssss.s.ssssss.sssss.ssssssssssssssssss.ssssss.ss.sssssssssss.ssssss23400 mean training reward: -1.42
# .ss.sssssssssssssssssssssssssssssssssssssss.s.sssssssssssss...ssssssssssssss.sssssssssss.sssssssssss23500 mean training reward: -1.64
# ssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssss.ssssssssssssssssssssssssssssssss23600 mean training reward: -1.53
# sssssss.sssssss.ssssssssssss.sssssssssssssss.ssssssssssssssssss.ssss.ss.ss.ssssssssssssssssss.ss.sss23700 mean training reward: -2.06
# ssssssssss.ssssssssssssssssssssssssssss..s.sssssssssssssssssssssssssssssssssssssssssssssssssssssssss23800 mean training reward: -2.26
# s.sssss.ssssssss..s.ssssssssssssssss.sssssssssssssssss.ssssss..sssssssssssssssssssssssssssssssssssss23900 mean training reward: -1.83
# ssss.sssss.ssssssssssssssssssssssssss.sssssssssssssssssssssssss.ssssssssssssssssssssssss.ssss..sssss24000 mean training reward: -1.80
# ss.s.ssss..s.sssssss.s.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.s24100 mean training reward: -1.60
# sssssssssss.sssssssssss.ssssss.ssssssssssssssssssss.ssssssssssssssss.ss.sssssss.sss.s.ssssssssssssss24200 mean training reward: -1.45
# ssssssssssss.sssssssssssss.sssssssssssssss.ssssssssssssss.ss.sssssssssssssssssssssss.sssssss..ssssss24300 mean training reward: -1.95
# ssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssss.ssssssssssss.s24400 mean training reward: -1.43
# ssssssssssss.ssssss.ssss.s.ssss.ssssssssssssssssssssssssssssssssss.ssssssss.s.ssss.ssssss.ssssssssss24500 mean training reward: -1.02
# sssssssssssssssssssssssssssssssssssssss..sssss.sssssssssssssssssssssssssssssssssssssssssssssssssssss24600 mean training reward: -1.73
# sssssssssssss.sssssss..ssssssssss.ssssssssss.sss.s.ssssssssss.ssss.ss.s.ssssssssssssssssss.sssssssss24700 mean training reward: -1.67
# sss..ssssssssssssssssss.ssssssss.s.sssssssssssss.s.s.sssssssssssssssssssssssssssssssssssssssssssssss24800 mean training reward: -1.89
# ssssssss.ssssssssssss.ssssss.sss.sssss.sssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssss24900 mean training reward: -2.46
# .ssss.sssssssssssssss.ss..sssssssssss.ss...sssssssssssssssssssssssssssssssssssssssssssssssssssssssss25000 mean training reward: -1.90
# ssssss.ssssssssssssssssss.ssssssssssssssssssssssssssssssssss..ssssssssssssssssssssssssssssssssssssss25100 mean training reward: -2.02
# ssssssssssssssssssssssss.sssssssssssssssss.ssss.ssssssssssssssssssssssss.sssssssssssssssssssssssssss25200 mean training reward: -2.21
# sssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssss25300 mean training reward: -2.32
# ssssss.s.ss.sssssssssssssssssssssssssssssssssssssssssssssssWsssssssssss.ss.sssssssssssssssssssssssss25400 mean training reward: -2.41
# sssssssssssssssssss.sssssssssssss.sssssssssssssssssss.sssssss.s..sssssssssssssss.sssssss.sssssssssss25500 mean training reward: -2.14
# ssssss.sssssssssssssss.ss.ssssssssssssssssssss.sssssssssssssssssssss.sssssssssssssssssssssssssssssss25600 mean training reward: -1.41
# s.sssssssssssssssssssssssssssss.sssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssss25700 mean training reward: -1.21
# sssssssssssssssssss.sssssssssss.ss.sssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssss.ss25800 mean training reward: -1.59
# sss.ssssssssssssssssssss.sssssssssssssssss.sssssssssssssssss.sssssssss.sss.ss.ssssssssssssssssssssss25900 mean training reward: -1.47
# sssssssssssssssssss.ssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssss26000 mean training reward: -1.93
# ssssssssssssssssssssssss..ssssssss.sssssssss.ssssssssss.ssssssssss.ss.ss.sssssssssssssssssssssssssss26100 mean training reward: -2.51
# ssssssssssss.sssssssssssssss..ssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssss26200 mean training reward: -1.78
# .ssss.ssssssssssssssssss.ssssss.ssssssss.Ws.s.ssssssssssssssssssssssssssssssssssssssssssssssssssssss26300 mean training reward: -2.23
# sss.sssssssssssssssssssssssssssssssssss.sss.ssssssssss.sss.ssssssssssssssss..sssssssssssssssssssssss26400 mean training reward: -2.33
# sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sss.ssssssssssssssssssssssssssssss26500 mean training reward: -1.86
# s.sssss.ssssssssssssssssssss.s...ssssssss.ssssssssssssssssssssssss.ssssssssss.sssssssssssssssss.ssss26600 mean training reward: -2.25
# ss.ssssss.sssssss.sss..ss.sss.ssssssssssssssssss.ssssssssss.ss.s.ss.ssssssssssssssssssssssssssssssss26700 mean training reward: -1.66
# sssssssssssssssssssssssssssssssssss.ssssssssssss.ssssss.ssssss.ssssss..ssssssssssssssssss.ssssssssss26800 mean training reward: -1.55
# ssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss..sssssssssssssssssssss26900 mean training reward: -1.99
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssss.sss.ssss.sssW.ss..ss.ss.sss27000 mean training reward: -1.80
# ss..sss.ss.sssssssssssssssssssssss.ssss.s.ssssssssssssssssssssssssssssssssssssssssssssssssssss..ssss27100 mean training reward: -1.26
# ssss.ssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssss.sss27200 mean training reward: -1.29
# ssssssssssssssssssssssss.ssssssssssss.ssssssssssssssssssssssss.ssssssssssssssssssssssss.ssssssssssss27300 mean training reward: -2.02
# ssssssssssssssssss.s.Ws.ssssssssss...sss.s.sssssssssssssssssssssssssssssssssssssssssssssssssssssssss27400 mean training reward: -0.90
# ssssssssssssssss.sssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssss.sss27500 mean training reward: -1.02
# sssssssssssss.ssssssssssssssssssssssssss.sssssssssss...sssssssss.sssssssssssssss.ssssssssss.ssssssss27600 mean training reward: -1.77
# .ssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssssssss.sssssssssssssssssssssssssss.ssss27700 mean training reward: -1.89
# sssssssss.ssssssssssssssssssssssssssssssssss..s.s.s..ss.Ws.s.ss.s.sss.ssssssss.ssssss.ssssssss.sssss27800 mean training reward: -1.74
# sssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssss.sss.sss.sssssssssssssssssss27900 mean training reward: -2.31
# ssssssssssssssssssssssssssssss.ssssssssssssssssssssss.ssssss.s.ss.s.s.ssss.sssssssssssssssssssssssss28000 mean training reward: -1.59
# sssssssssssssssssss.sssssssssssssssss.ss..sssssssssssssssssssss..ssssssssssssssss.ssssssssssssssssss28100 mean training reward: -1.39
# ssssss.sssssssssssssss.sssssssssssssssssssssssss.sssssssssssss.sssssssssssssssssssssssssssssssssssss28200 mean training reward: -1.35
# ss.sssssssss.sssssssss..sssssssssss..ssss.ssssssssssssW.s.ss.ssssssss.ss.s.ssssssssssss.ssssssssssss28300 mean training reward: -1.33
# sssssssssssssssss..s.sssssss.sssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssss.s28400 mean training reward: -1.37
# ssssssssssssssssss.sssssssssssssssssssssssss.s.ssssssssssss.....ssssssss....s...s..sssssssssssssssss28500 mean training reward: -2.20
# ssssssssssssssss.ssssssssssssssssssssss.sssssssssssssssssssssssss.ss.sssss.ssssss.sssss.ssssssssssss28600 mean training reward: -1.24
# ssssssssssssssssssssss.sssssssssssssssss.sssss..ssssssssssssssss.sssssssssssssssssssssssssssssssssss28700 mean training reward: -1.68
# sssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssss.sssssssssssssss28800 mean training reward: -1.67
# sssssssssssssss.sss....s..sss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss28900 mean training reward: -1.85
# ss.sss.s.sss.ssssssss.sssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssss29000 mean training reward: -1.42
# sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssss29100 mean training reward: -0.92
# sssss.ssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssss29200 mean training reward: -1.52
# sssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sss.s.sss.ssssssssss.sssssss29300 mean training reward: -1.55
# ssssssssssssssssssssssssssssss.ssssssssssssssss.sssssssssss.sssssssssssssss.ssssssssssssssssssssssss29400 mean training reward: -1.91
# sssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssss29500 mean training reward: -1.80
# ssssssssssssssssssssssss..sss....ssssss.s.ssssssssssssssssssss.sssssss.ssssssssss.ss.sssssssssssssss29600 mean training reward: -0.81
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.....s.ssss.ss.sss..sss.W......s.s..29700 mean training reward: -2.21
# s.ssss...s.sssss.....Ws.ss.s.sssssssssssssssssssssssssssssssssssssss.s.s.sss...ss..sss.ssss..sss.sss29800 mean training reward: -1.30
# .sssss.ss.ssssssssssss.sssssssssssssssss.s.sssssssssssssssssssss.sssssssssssssssssssssssssssssssssss29900 mean training reward: -0.40
# sssssssssssssssssssssss.sssss.ssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssss30000 mean training reward: -0.81
# ssssssssssssssssssss.ssssssssssssssssssssssssssssssssss.sssssssssssssssssssssssssss.ssssssssssss.sss30100 mean training reward: -1.52
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss30200 mean training reward: -1.48
# sssssssssssssssssssssssssss.sssssssss.s.sss..s.sssssssssssssssssssssssss.ssssssssssssssssssssssss.ss30300 mean training reward: -1.87
# .Wssssssssssssssssssssssssssss..ssssssss..ssssssssssssssssssssssssssssssssssssssssssssssssssssssss.s30400 mean training reward: -0.92
# s.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss..ssssssssssssssssssssssssssss30500 mean training reward: -0.78
# .sss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssss30600 mean training reward: -1.35
# sssssssssssssss.ss.sssssssss.sssssssssssssssss.ssssssssssssssssssssssssssssss.ssssss.sss.ssssss.ssss30700 mean training reward: -1.83
# ssssssssss.ssssssssssssssssssssss...ssssssss.ssssssssss.ssss.ssss.ssssssssss.sssWsss..ssssssssssssss30800 mean training reward: -3.21
# ssssssssssssssssssss.sssssssssssssssssss.ssssssssssssssssssssssssssss.sssss.ssssssssssssss.sssssssss30900 mean training reward: -2.11
# .s.ss.ssssssssss.........sss.........s.s..sss..ssssssssss.ss.ssssssssssss.s.ssssssssssssssssssssssss31000 mean training reward: -1.73
# sssssssssssssssssssWsss.ssssss.sssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss31100 mean training reward: -1.01
# ssssssssssssssssssssssssssssss..ssss.ssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssss.31200 mean training reward: -0.70
# sssssssssssssssssssssssssssssssssss.sssssss.ssss.ssssssssssssssssssssssssssss.ssssssssssssssssssssss31300 mean training reward: -0.97
# ssssssssssssssssssssssssssssssssssss.sssssssss.ssssssssssssss.ssssss.ss..ssss...ss.sssssssssssssssss31400 mean training reward: -1.14
# sssss.ssssssssss.sss.ssssssssssssssssssssssssss.sss..sssssssssss.sssssssss.sssssssssssssssss.sss.sss31500 mean training reward: -0.83
# ssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss31600 mean training reward: -1.10
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss31700 mean training reward: -1.36
# ssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss31800 mean training reward: -1.31
# sssssssssssssssssssssssssssss..ss.Wsss..sW...s.sss.sssssssssssss.sss..ssssssssssss.sssssssssss..ss.s31900 mean training reward: -2.27
# ss.ssssssssssssssss.sss..ss..sss.ssssssss.s.ss..s.ssssssssssssssssssssssssssssssssssssssssssssssss..32000 mean training reward: -2.89
# s.sssssss.ssssssssssssssssssssssssssssssssssss..sssssssss.ssssssssssssssssssssssssssss.sssssssssssss32100 mean training reward: -0.91
# sssssssssss.sssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss32200 mean training reward: -1.32
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ss.s..s.s..sss.ss....s.ss.ss.32300 mean training reward: -2.92
# ss.ssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssss....sssssssssssssssssssss.sssssss32400 mean training reward: -1.06
# s..ss.s.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssss.ssssssssssss32500 mean training reward: -0.52
# ssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssss32600 mean training reward: -0.83
# ssssssssssssssssssssssssssssssssssssssssssssssss......s.s.s..sss.s.ssssss.s.ssssssssssWs.ssssss.Wsss32700 mean training reward: -1.95
# ssssssssssss..sss.ss.sssssssssssss..sss.ssss.sssssssss.ssssss.s.sssss.sss.ss.s...s..s.s.s.ssssssssss32800 mean training reward: -1.57
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.s32900 mean training reward: -0.65
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssss.ssssssssssss33000 mean training reward: -0.31
# sssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss33100 mean training reward: -0.58
# ssssssssssssss.ssssssssssssssssssssssssssssssssssssssss.s..sssssssssssssssssssssssssssssssssssssssss33200 mean training reward: -0.68
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ss.sss.s....s......33300 mean training reward: -0.68
# .s....s.........s.s.s...........s...........s...........ss...s..s......s...s....s........ss.s..W.s.s33400 mean training reward: -1.27
# ......s...s.......ss...ss..s..s.....s......s.......s.....s........ss....s........W..s.ss........s.s.33500 mean training reward: -1.41
# s..s.s....s....ss......s.s.s...s...s.s..sss..s....s...s.ss.Ws.ss..sss....ssssss..s...s..ssss..ss.s.s33600 mean training reward: -0.98
# ssssss.ssssWss..s.ssss.s.sssssssssssss.sssssss.s.ssssssssssss.ssssssssssssssssssssssssssssssssssssss33700 mean training reward:  0.06
# ssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss33800 mean training reward: -0.60
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss33900 mean training reward: -0.53
# sssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ss.ss.s34000 mean training reward: -0.33
# sssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ss34100 mean training reward: -0.72
# ssssssssssssss..ssssssssssssssssssssssssssssssssssss.s.ssss.s.ssssssssssssss.ss.ssssss.sssssssssssss34200 mean training reward: -0.70
# sssssssssssss.sssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssss34300 mean training reward: -0.44
# ssssssss.sss.sss.ssssssssssssssssssssssss.s.ssss..ss.s.s.ss.ss.ss.sss...sss..ss...ss.....s..s.ss....34400 mean training reward: -0.76
# ..s.s...Ws.....W.sssss...s..ss......s.s.ss..ss..s......s...W...........W....s.......ss..............34500 mean training reward: -0.85
# .W.W...s..........Ws.s.......s...sss.......s.s..s..............s........s........s...........s...sss34600 mean training reward: -0.79
# ...s..................s......s.....s.s....s...s.....s....s.W....ss.s...ss................s........ss34700 mean training reward: -1.09
# .........s...s.....s..s......s.........s...s.......s...s..s...s..s.s....W......s..s..s.s...s....s...34800 mean training reward: -1.18
# .s.ss....W...ss.s...s....ss...s.s...ss..s........ss....s.......ss...s.............ss...s....s..s..ss34900 mean training reward: -1.02
# .....s.s...s.s.ss.s.ssss.ss...s..ss.ssss.sssss....ssssss.ssssssssssssssssssssssssssssssssssssss.ss.s35000 mean training reward: -0.88
# sss.sssssssss.ss.ss.ssss.ssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssss35100 mean training reward: -0.11
# sssssssssssssssssssssssssssssssssssss.sssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssss35200 mean training reward: -0.34
# ssssssssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss35300 mean training reward: -0.32
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss35400 mean training reward: -0.86
# sssssssssssssssssssssssss.sssssss.ssssssssssssssssssss.ssWsssss.sssssss.ssssss..sss.s.ssss..sss.ss..35500 mean training reward: -0.04
# .......ss.ss....ss.....s.sss.ss.s.sss..s.s.ssssss.s..s..sssssssssss.ss....s..s..s...sssss...s.sss.s.35600 mean training reward: -0.78
# sssss.s.ss.sssss..ssss.ssssss.ssss..sssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssss35700 mean training reward: -0.05
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss35800 mean training reward: -0.30
# ssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss35900 mean training reward: -0.38
# sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssss36000 mean training reward: -0.96
# .ssssssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssssss.ssssWs.sssss.sss.sssssssssssss36100 mean training reward: -1.72
# sssssss.sssssss..ssssssssssssssssssssss.s......s......W..............s.ss...s.........s..........s..36200 mean training reward: -1.70
# ..........s......W...W.....s.ss....s.s.......W......s.....s..........................W...s..........36300 mean training reward: -1.34
# ..s.....s.......s................ss.............ss.......W........s.......s.......s.................36400 mean training reward: -1.01
# .s..................s......W......s..s....s.s....s........s......s...............ss.s.......s.......36500 mean training reward: -1.52
# .s...................................s.......s..........................s...........................36600 mean training reward: -1.37
# .....s..s.W......s............................s.......s.....s.........s.............s......s........36700 mean training reward: -1.11
# ....s...............s..............s......ssW...............................s.......................36800 mean training reward: -1.48
# .......s.....W.s.....s..s.......s....W..........s..ss............ssss....s...........s....s.........36900 mean training reward: -1.18
# ....ss...s..............s..............s....s......s........s....s............s........s.W....W....s37000 mean training reward: -1.10
# ........................................s......s...ss.....s...............................s.s.......37100 mean training reward: -1.24
# ...s....s..........................s..................ss.........s......s............s..s..ss..s.sWs37200 mean training reward: -1.15
# s.s...........s.s.......Ws...............s...W.s.s.......W....s...s....ss..s.....s..................37300 mean training reward: -1.07
# W.s.....s.......s...........s.s.s..s.......s..ss......W.....Ws..sss..s...s..........s..s....ss..s..s37400 mean training reward: -1.30
# s...s.s..s..s.s............sss........ss.........s...s.....s..s..s..s......s..........s...s..s...s..37500 mean training reward: -1.23
# ......s.s.....s..s..s....ss.s.s.ss.ss..sss.s.sss..ss.sss.ss...ss.ssss..sss.s.WsssW..s.ssss..s.ss.sss37600 mean training reward: -0.47
# s..sss..s.....s..ssss.s..s.s.sss...s.s.ss.s..s.ssss..sss..sss.sss.s...s..s.sss..sss.sssss..sssssssss37700 mean training reward: -0.48
# ss.ssss.sssssssss.ssss.ssssssss.ssssssssssssssssssssssssssssssssss.sssssssssss.ssssssssssssss.ssssss37800 mean training reward: -0.20
# sssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssss.sssssssss37900 mean training reward: -0.45
# ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss38000 mean training reward: -0.64
# ssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssss.sss.ssssssss38100 mean training reward: -0.90
# sssssssssss.sssssssssssssssssss..sss.ss.s.sssssss.sssssssssssssssssss.ssssssss.sss.sss.sssssssssssss38200 mean training reward: -1.43
# sss.sssssssss.sss.ssssss.sssssssss.sssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.sss.s38300 mean training reward: -1.09
# sssssssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssss38400 mean training reward: -1.30
# ssssssssssssssssssssssssssssssss.sss.................s.........s..............s.................s...38500 mean training reward: -1.70
# ........Wss......s.........W...............W......s...............Ws.......W..s......s...Ws.s.......38600 mean training reward: -0.96
# ....s..............s.............s....................W.................s.s...................s.....38700 mean training reward: -1.19
# ...................................W...W............W........s..........W...s...s.W...s.............38800 mean training reward: -0.94
# ........s......s...................................................s.........s....s..........s......38900 mean training reward: -1.26
# .s.W.s..........W.............s....s....s..........s.......................s........................39000 mean training reward: -0.97
# ....W..s...............................s...............s..............s..............s.....s.W......39100 mean training reward: -1.17
# .W.......................s......................W...........s...........s...........................39200 mean training reward: -1.15
# ..............................s.....Ws..sWs............s........................W.s.................39300 mean training reward: -1.37
# .................ss.s...............s...............s.....W...................s..........W..........39400 mean training reward: -0.95
# .............W...........................s................s......................................s..39500 mean training reward: -1.09
# ..........................................s...s..........................s..........................39600 mean training reward: -1.16
# .........W......W..W.s....s...s...............................................s.....................39700 mean training reward: -1.00
# ................................................s..............................s...W................39800 mean training reward: -1.10
# .......................................s..........W..............................s..................39900 mean training reward: -1.18
# ..............s.......W......W..........W................................................s..........40000 mean training reward: -1.06
# .........s............s...W......W...W...........W.....W.........................s...s.....W........40100 mean training reward: -0.97
# .W............s......W....W..........s.....s...........W.................s..........s.......W...s...40200 mean training reward: -0.96
# ................W.......................W.........W....W..................s.........................40300 mean training reward: -1.01
# .....................W..........W...........s..............s.....W...Ws.............................40400 mean training reward: -1.07
# .............sW.............ss.....W.....W...s..............sW.............................W.s......40500 mean training reward: -0.99
# ............................W................................W.....................................W40600 mean training reward: -1.10
# ...s...........................................s...........................s..W.....................40700 mean training reward: -1.10
# .........................................s................................s.........................40800 mean training reward: -1.26
# .s.s......s........W......s......................................s..........Ws....................s.40900 mean training reward: -1.16
# .............................s.........................................s............s...............41000 mean training reward: -1.05
# ......................s.............................................................s.s........W....41100 mean training reward: -1.04
# ............s.........................................................s........W....................41200 mean training reward: -1.10
# .................................s..............s..........s...................Ws...................41300 mean training reward: -1.00
# ..............................W......s...................W......................W...................41400 mean training reward: -1.03
# ...............W...........s.........................................................s..............41500 mean training reward: -1.28
# .......................................s..........s............................s.sW............s....41600 mean training reward: -1.22
# ............................sW......................................................................41700 mean training reward: -1.03
# .............................................................................W......................41800 mean training reward: -1.07
# .................................................................W....W....W...s......s.......s.....41900 mean training reward: -1.02
# ..W..W............s...............s......................s.W........................................42000 mean training reward: -1.06
# ....................................................................................................42100 mean training reward: -1.35
# ........W...............................................W.................s....ss...................42200 mean training reward: -1.14
# ............................W.......................................................................42300 mean training reward: -1.06
# ..................W.................................W...............................s......W........42400 mean training reward: -1.02
# ............................W.........s...............s...............s....................W....W...42500 mean training reward: -1.00
# ......W..........................................sW...........................................W.....42600 mean training reward: -1.14
# ...W............................W........................W............................W.............42700 mean training reward: -1.00
# ......................................s.............................................................42800 mean training reward: -1.18
# .................W............................................W.....................................42900 mean training reward: -1.04
# ..........W.........................s...........................W...................................43000 mean training reward: -1.02
# ................s.............................W..........W......................W........s..........43100 mean training reward: -1.02
# ....................s.....................................s..................................s......43200 mean training reward: -1.02
# ............................................W............................................W..........43300 mean training reward: -1.03
# ....W.......W.......................................................................................43400 mean training reward: -1.10
# .........................................s...........................W........................s.....43500 mean training reward: -1.06
# ...................................................................W..W..........................W..43600 mean training reward: -1.08
# ...............W........................................W.....................................W.....43700 mean training reward: -1.07
# ......................W....W.....................................s..................................43800 mean training reward: -1.03
# ............................................................W..........................s............43900 mean training reward: -1.08
# ...............s........................W....................W...............s......................44000 mean training reward: -1.03
# ............sW.................W...............s.......W........s..........................W........44100 mean training reward: -0.91
# ..............................................................W.....................................44200 mean training reward: -1.06
# W..................W...........W.............s....W.................................................44300 mean training reward: -0.99
# .........................................W..........W......s...W..................W.................44400 mean training reward: -1.00
# ...................s........................................................W.......................44500 mean training reward: -1.08
# ...........................................................W..s..................W..................44600 mean training reward: -1.01
# ..................................................sW.......................s.........W.........W....44700 mean training reward: -1.00
# ..............................W.............W...W.......................................W...........44800 mean training reward: -1.22
# ....................................................................................................44900 mean training reward: -1.11
# .W..................................W..............W........W.......................................45000 mean training reward: -0.99
# ....interrupt
# CPU times: user 9h 51min 31s, sys: 1h 14min 7s, total: 11h 5min 39s
# Wall time: 11h 9min 23s

# %%
## If there is an error resize the wins and num_episodes to still be able to print
if(len(rewards)!=num_episodes):
  new_lenght = len(rewards)
  num_episodes = new_lenght
  wins = wins[:new_lenght]

# %% [markdown]
# # Plot results
#
# Visualize training statistics

# %%
# Plot training statistics
def moving_average(a, n=10) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

plt.figure(figsize=(16, 9))
#Plot training rewards
plt.subplot(511)
plt.title('training rewards')
plt.plot(range(1, num_episodes+1), rewards)
plt.plot(range(1, num_episodes+1), moving_average(rewards))
plt.xlim([0, num_episodes])
#Plot wins
plt.subplot(512)
plt.title('wins')
plt.plot(range(1, num_episodes+1), wins)
plt.plot(range(1, num_episodes+1), moving_average(wins))
plt.xlim([0, num_episodes])
#Plot training lengths
plt.subplot(513)
plt.title('training lengths')
plt.plot(range(1, num_episodes+1), lengths)
plt.plot(range(1, num_episodes+1), moving_average(lengths))
plt.xlim([0, num_episodes])
#Plot training loss
plt.subplot(514)
plt.title('training loss')
plt.plot(range(1, num_episodes+1), losses)
plt.plot(range(1, num_episodes+1), moving_average(losses))
plt.xlim([0, num_episodes])
#Plot epsilon
plt.subplot(515)
plt.title('epsilon')
plt.plot(range(1, num_episodes+1), epsilons)
plt.xlim([0, num_episodes])

plt.tight_layout(); plt.show()

#Plot actions done in each episode
import pandas as pd
from collections import Counter

size = len(actionlog)
y = np.zeros((size,6))

for i in range(size):
  n = Counter(actionlog[i])
  for j in range(6):
    y[i][j] = n[j]
    
x = np.arange(size)
df = pd.DataFrame(y, index=x)

df = df.divide(df.sum(axis=1), axis=0)
ax = df.plot(kind='area', stacked=True, title='Actions over the episodes', figsize=(19.5, 2),legend = 'reverse')

ax.set_xlabel('Episodes'); ax.set_ylabel('Percent (%)')
ax.margins(0, 0) # Set margins to avoid "whitespace"

plt.show()

# %% [markdown]
# # Save file
#
# Save trainned models and download it in a file

# %%
from google.colab import files
torch.save(agents[3].qnet.state_dict(), "week15_cnnSimple.pth.tar")
files.download( "week15_cnnSimple.pth.tar" )

# %% [markdown]
# # Animation
#
# Use emojii render to visualize a game with the pre-trainned agent.

# %%
lookup = ['Stop', 'Up', 'Down', 'Left', 'Right', 'Bomb']

# %%
import emoji

def myRender(stage):
  for i in stage:
    for j in i:
      if(j==0): # free ground
        j = emoji.emojize(":white_question_mark:")
        #j = emoji.emojize(":white_large_square:")
      elif(j==1): # stone wall
        j = emoji.emojize(":mountain:")
      elif(j==2): # wooden wall
        j = emoji.emojize(":seedling:")
      elif(j==3): # bomb
        j = emoji.emojize(":bomb:")
      elif(j==4): # fire     
        j = emoji.emojize(":fire:")
      # 5 is fog
      
      #power ups
      elif(j==6): # extra bombs item     
        j = emoji.emojize(":pistol:")
      elif(j==7): # extra firepower     
        j = emoji.emojize(":collision:")
      elif(j==8): # kick     
        j = emoji.emojize(":running_shoe:")
      
        
      elif(j==10 or j==11 or j==12): #opponent
        j = emoji.emojize(":smiling_face_with_horns:")
      elif(j==13): #our agent
        j = emoji.emojize(":smiling_face_with_sunglasses:")

      print(j, end = "")
    print("")    

this_stage = s[3]['board']
myRender(this_stage)

# %%
from IPython.display import clear_output
import time

num_episodes = 1
shapedreward = RewardsShaper()

rewards, lengths, losses, epsilons, wins, actionlog = [], [], [], [], [0] * num_episodes, []
for i in range(num_episodes):
    # init new episode
    s, ep_reward, ep_loss, ep_actions = env.reset(), 0, 0, []
    q_values = []
    r = 0

    for j in range(episode_limit):
        actions = env.act(s)
        s1, r, done, info = env.step(actions)
        
        clear_output()
        #print(actions[3],lookup[actions[3]])
        #if(j!=0):
        #  print(np.round_(agents[3].Q.data.cpu().numpy()))
        print()
        myRender(s[3]['board'])
        print()
        time.sleep(1.5)
        
        if(13 in s[3]['alive']):
            shaped, suicude = shapedreward.run(s, actions, s1, done, info)
            ep_reward += shaped
            r[3] += shaped
            loss = agents[3].afterstep(s1[3], r[3], actions[3])

            ep_loss += loss.item()
            q_values.append(agents[3].Q)
        else:
          done = True
          
        s = s1
        if done: break

    # episode is finished 
    if("winners" in info):
      if(3 in info["winners"]):
        ep_reward += 1
        wins[i] = 1
      else:
        ep_reward -= 1

    print(".",end="")
