# %% [markdown]
# # Setting up and Initialization
#
# **Note:** Most of the times it is needed to reinitializate the enviorment to correctly execute the whole program due to problems on importing libraries. If after executing the first cell of the *Code* section (third cell from the beginning), any error appears, please, reinitializate the enviorment and execute everything again.

# %%
#Set up and import all libraries and utilities needed to execute the Pommerman project
import os
import sys
import numpy as np

#Download Pommerman enviorment from the repository
# !git clone https://github.com/esbenlkruse/Pommerman

os.chdir('Pommerman')
os.chdir('playground')

# !python setup.py install

from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# !pip install emoji

# install gym
! pip install git+https://github.com/openai/gym
# Out:
# fatal: destination path 'Pommerman' already exists and is not an empty directory.
# running install
# running bdist_egg
# running egg_info
# writing pommerman.egg-info/PKG-INFO
# writing dependency_links to pommerman.egg-info/dependency_links.txt
# writing entry points to pommerman.egg-info/entry_points.txt
# writing requirements to pommerman.egg-info/requires.txt
# writing top-level names to pommerman.egg-info/top_level.txt
# reading manifest file 'pommerman.egg-info/SOURCES.txt'
# writing manifest file 'pommerman.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pommerman
# copying build/lib/pommerman/forward_model.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/runner
# copying build/lib/pommerman/runner/docker_agent_runner.py -> build/bdist.linux-x86_64/egg/pommerman/runner
# copying build/lib/pommerman/runner/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/runner
# creating build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/cli/run_battle.py -> build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/cli/train_with_tensorforce.py -> build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/cli/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/cli
# copying build/lib/pommerman/configs.py -> build/bdist.linux-x86_64/egg/pommerman
# copying build/lib/pommerman/characters.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/v2.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/v0.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/v1.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/envs/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/envs
# copying build/lib/pommerman/constants.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/base_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/http_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/random_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/simple_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/docker_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/player_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/tensorforce_agent.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/agents/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/agents
# copying build/lib/pommerman/graphics.py -> build/bdist.linux-x86_64/egg/pommerman
# creating build/bdist.linux-x86_64/egg/pommerman/helpers
# copying build/lib/pommerman/helpers/__init__.py -> build/bdist.linux-x86_64/egg/pommerman/helpers
# creating build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Fog.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-9.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/ExtraBomb.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-3.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Kick.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Cousine-Regular.ttf -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent2-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent1.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent1-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Wood.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Rigid.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-10.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Passage.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-8.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent0.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/X-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Flames.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent2.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent0-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Skull.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-1.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-7.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-6.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent3.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/AgentDummy-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Agent3-No-Background.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-2.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-5.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/AgentDummy.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/Bomb-4.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/resources/IncrRange.png -> build/bdist.linux-x86_64/egg/pommerman/resources
# copying build/lib/pommerman/utility.py -> build/bdist.linux-x86_64/egg/pommerman
# copying build/lib/pommerman/__init__.py -> build/bdist.linux-x86_64/egg/pommerman
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/forward_model.py to forward_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/runner/docker_agent_runner.py to docker_agent_runner.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/runner/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/cli/run_battle.py to run_battle.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/cli/train_with_tensorforce.py to train_with_tensorforce.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/cli/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/configs.py to configs.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/characters.py to characters.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/v2.py to v2.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/v0.py to v0.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/v1.py to v1.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/envs/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/constants.py to constants.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/base_agent.py to base_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/http_agent.py to http_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/random_agent.py to random_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/simple_agent.py to simple_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/docker_agent.py to docker_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/player_agent.py to player_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/tensorforce_agent.py to tensorforce_agent.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/agents/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/graphics.py to graphics.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/helpers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/utility.py to utility.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pommerman/__init__.py to __init__.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pommerman.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/pommerman-0.2.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pommerman-0.2.0-py3.6.egg
# removing '/usr/local/lib/python3.6/dist-packages/pommerman-0.2.0-py3.6.egg' (and everything under it)
# creating /usr/local/lib/python3.6/dist-packages/pommerman-0.2.0-py3.6.egg
# Extracting pommerman-0.2.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# pommerman 0.2.0 is already the active version in easy-install.pth
# Installing pom_battle script to /usr/local/bin
# Installing pom_tf_battle script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/pommerman-0.2.0-py3.6.egg
# Processing dependencies for pommerman==0.2.0
# Searching for pylint==1.9.3
# Best match: pylint 1.9.3
# Processing pylint-1.9.3-py3.6.egg
# pylint 1.9.3 is already the active version in easy-install.pth
# Installing epylint script to /usr/local/bin
# Installing symilar script to /usr/local/bin
# Installing pylint script to /usr/local/bin
# Installing pyreverse script to /usr/local/bin
# Installing epylint script to /usr/local/bin
# Installing pylint script to /usr/local/bin
# Installing pyreverse script to /usr/local/bin
# Installing symilar script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/pylint-1.9.3-py3.6.egg
# Searching for isort==4.3.4
# Best match: isort 4.3.4
# Processing isort-4.3.4-py3.6.egg
# isort 4.3.4 is already the active version in easy-install.pth
# Installing isort script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/isort-4.3.4-py3.6.egg
# Searching for astroid==1.6.5
# Best match: astroid 1.6.5
# Processing astroid-1.6.5-py3.6.egg
# astroid 1.6.5 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/astroid-1.6.5-py3.6.egg
# Searching for jsonmerge==1.5.2
# Best match: jsonmerge 1.5.2
# Processing jsonmerge-1.5.2-py3.6.egg
# jsonmerge 1.5.2 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/jsonmerge-1.5.2-py3.6.egg
# Searching for requests==2.18.4
# Best match: requests 2.18.4
# Adding requests 2.18.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Flask==0.12.4
# Best match: Flask 0.12.4
# Processing Flask-0.12.4-py3.6.egg
# Flask 0.12.4 is already the active version in easy-install.pth
# Installing flask script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/Flask-0.12.4-py3.6.egg
# Searching for ruamel.yaml==0.15.81
# Best match: ruamel.yaml 0.15.81
# Processing ruamel.yaml-0.15.81-py3.6-linux-x86_64.egg
# ruamel.yaml 0.15.81 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/ruamel.yaml-0.15.81-py3.6-linux-x86_64.egg
# Searching for Pillow==5.3.0
# Best match: Pillow 5.3.0
# Processing Pillow-5.3.0-py3.6-linux-x86_64.egg
# Pillow 5.3.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/Pillow-5.3.0-py3.6-linux-x86_64.egg
# Searching for scipy==1.1.0
# Best match: scipy 1.1.0
# Adding scipy 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for gym==0.10.9
# Best match: gym 0.10.9
# Adding gym 0.10.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for docker==3.6.0
# Best match: docker 3.6.0
# Processing docker-3.6.0-py3.6.egg
# docker 3.6.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/docker-3.6.0-py3.6.egg
# Searching for six==1.11.0
# Best match: six 1.11.0
# Adding six 1.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for mccabe==0.6.1
# Best match: mccabe 0.6.1
# Processing mccabe-0.6.1-py3.6.egg
# mccabe 0.6.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/mccabe-0.6.1-py3.6.egg
# Searching for wrapt==1.10.11
# Best match: wrapt 1.10.11
# Adding wrapt 1.10.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for lazy-object-proxy==1.3.1
# Best match: lazy-object-proxy 1.3.1
# Processing lazy_object_proxy-1.3.1-py3.6-linux-x86_64.egg
# lazy-object-proxy 1.3.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/lazy_object_proxy-1.3.1-py3.6-linux-x86_64.egg
# Searching for jsonschema==2.6.0
# Best match: jsonschema 2.6.0
# Adding jsonschema 2.6.0 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2018.11.29
# Best match: certifi 2018.11.29
# Adding certifi 2018.11.29 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.6
# Best match: idna 2.6
# Adding idna 2.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.22
# Best match: urllib3 1.22
# Adding urllib3 1.22 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for itsdangerous==1.1.0
# Best match: itsdangerous 1.1.0
# Adding itsdangerous 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Click==7.0
# Best match: Click 7.0
# Adding Click 7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Werkzeug==0.14.1
# Best match: Werkzeug 0.14.1
# Adding Werkzeug 0.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.10
# Best match: Jinja2 2.10
# Adding Jinja2 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.14.6
# Best match: numpy 1.14.6
# Adding numpy 1.14.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyglet==1.3.2
# Best match: pyglet 1.3.2
# Adding pyglet 1.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for websocket-client==0.54.0
# Best match: websocket-client 0.54.0
# Processing websocket_client-0.54.0-py3.6.egg
# websocket-client 0.54.0 is already the active version in easy-install.pth
# Installing wsdump.py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages/websocket_client-0.54.0-py3.6.egg
# Searching for docker-pycreds==0.4.0
# Best match: docker-pycreds 0.4.0
# Processing docker_pycreds-0.4.0-py3.6.egg
# docker-pycreds 0.4.0 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/docker_pycreds-0.4.0-py3.6.egg
# Searching for MarkupSafe==1.1.0
# Best match: MarkupSafe 1.1.0
# Adding MarkupSafe 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for future==0.16.0
# Best match: future 0.16.0
# Adding future 0.16.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for pommerman==0.2.0
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Collecting git+https://github.com/openai/gym
#   Cloning https://github.com/openai/gym to /tmp/pip-req-build-gg7kdg7l
# Requirement already satisfied (use --upgrade to upgrade): gym==0.10.9 from git+https://github.com/openai/gym in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.14.6)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.11.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.3.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (2018.11.29)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym==0.10.9) (0.16.0)
# Building wheels for collected packages: gym
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-59k0e1b9/wheels/d5/72/8b/930cb346bdca1819ddcfc8f0325276ea09c92c3005f6c51a54
# Successfully built gym

# %%
#Check if gym library has been imported successfully
try: 
  import gym
  # !pom_battle
except ImportError:
    #In case of error reinitiate the enviorment (check Note at the beginning)
    print("Please restart and run all.")
# Out:
# Import error NSDE! You will not be able to render --> Cannot connect to "None"
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Starting the Game.
# Final Result:  {'result': <Result.Win: 0>, 'winners': [2]}
# Game Time:  0.621901273727417

# %% [markdown]
# # CODE
#
# Code developed to train Pommerman agents.

# %%
# Import more needed libraries
from pommerman.agents import SimpleAgent, RandomAgent, PlayerAgent, BaseAgent
from pommerman.configs import ffa_v0_fast_env
from pommerman.envs.v0 import Pomme
from pommerman.characters import Bomber
from pommerman import utility

# %matplotlib inline
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.nn import Linear, GRU, Conv2d, Dropout, MaxPool2d, BatchNorm1d, BatchNorm2d
from torch.nn.functional import relu, elu, relu6, sigmoid, tanh, softmax
import copy


# Instantiate the environment
config = ffa_v0_fast_env()
env = Pomme(**config["env_kwargs"])

# CUDA
use_cuda = torch.cuda.is_available()

device = torch.device("cuda:0" if use_cuda else "cpu")
print("Using device:", device)
# Out:
# Import error NSDE! You will not be able to render --> Cannot connect to "None"
# Using device: cuda:0

# %%
class QNetwork(nn.Module):
    """Q-network class (Deep Q-Network implementation)"""
    """It contains all the structure described on Model B"""
    
    #Constructor
    def __init__(self, n_channels, n_outputs, learning_rate):
        super(QNetwork, self).__init__()
        #Conv layer
        self.conv_1 = Conv2d(in_channels=n_channels,
                             out_channels=32,
                             kernel_size=3,
                             stride=1,
                             padding=1)
        #Conv layer
        self.conv_2 = Conv2d(in_channels=32,
                             out_channels=32,
                             kernel_size=3,
                             stride=1,
                             padding=1)
        # FFNN layer
        self.fc = nn.Linear(3872, 1933, bias=False)
        # Output layer
        self.out = nn.Linear(1933, n_outputs, bias=False)
        torch.nn.init.uniform_(self.out.weight, 0, 0.01)
        
        # SGD optimizer
        self.optimizer = optim.SGD(self.parameters(), lr=learning_rate)
    
    #Forward pass
    def forward(self, x):
       
        x = x.unsqueeze(0)
        x = self.conv_1(x)
        x = relu(x)
        
        x = self.conv_2(x)
        x = relu(x)
        
        x = x.flatten()
        
        x = self.fc(x)
        x = relu(x)
        x = self.out(x)
        return x
    
    #Loss
    def loss(self, q_outputs, q_targets):
        return torch.sum(torch.pow(q_targets - q_outputs, 2))
    
    #Update q-target   
    def update_params(self, new_params, tau):
        params = self.state_dict()
        for k in params.keys():
            params[k] = (1-tau) * params[k] + tau * new_params[k]
        self.load_state_dict(params)
      
def one_hot(i, l):
    """One-hot encoder for groups of observations"""
    a = np.zeros((len(i), l))
    a[range(len(i)), i] = 1
    
    return a
  

def featurize(obs):
    """Define observations and prepares it for the next step"""
    
    # Different elements of the observation
    position = obs["position"]
    board = obs["board"]
    bomb_blast_strength = obs["bomb_blast_strength"]
    bomb_life = obs["bomb_life"]
    ammo = [obs["ammo"]]
    blast_strength = [obs["blast_strength"]]
    can_kick =[obs["can_kick"]]
    actionlist = obs['actionlist']
    
    teammate = obs["teammate"]
    if teammate is not None:
        teammate = teammate.value
    else:
        teammate = -1
    teammate = [teammate]

    enemies = obs["enemies"]
    enemies = [e.value for e in enemies]
    if len(enemies) < 3:
        enemies = enemies + [-1]*(3 - len(enemies))
    enemies = enemies
    
    #Array of observations prepared for the next step
    output = np.array([board, bomb_blast_strength, bomb_life])
    return output

# %%
class OwnAgent(BaseAgent):
    """Implementation of our own agent, based on Model B"""
    #Constructor
    def __init__(self, character=Bomber):
        self._character = character
        #Number of channels
        self.n_channels = 3
        #Dimension of the output layer
        self.n_outputs = 6
        #Learning rate
        self.learning_rate = 0.0005
        #Discount rate
        self.gamma = 0.99 
        #Action list
        self.actionlist = [6,6,6,6,6,6,6,6,6,6]
        #Target tau
        self.tau = 0.01
        
        #Q-network
        self.qnet = QNetwork(self.n_channels, self.n_outputs, self.learning_rate)
        #Target Q-network
        self.target_qnet = QNetwork(self.n_channels, self.n_outputs, self.learning_rate)
        self.target_qnet.load_state_dict(self.qnet.state_dict())
        # GPU
        if use_cuda:
          self.qnet.cuda()
          self.target_qnet.cuda()
        
        self.Q = 0
        self.Q1 = 0
        
        #self.master = SimpleAgent(config["agent"](agent_id, config["game_type"]))
    
    # Act function
    def act(self, obs, action_space):
        
        obs['actionlist'] = self.actionlist
        # 1- do foward pass of current state to compute Q-values for all actions
        self.qnet.optimizer.zero_grad()
        self.Q = self.qnet(torch.from_numpy(featurize(obs)).float().to(device))
        
        # 2- select action with epsilon-greedy strategy
        if np.random.rand() > epsilon:
          a = self.Q.argmax().item()  
        else:
          a = env.action_space.sample()
        #Save action chosen
        self.actionlist.insert(0,a)
        del self.actionlist[10]
        return a
    
    # After step function
    def afterstep(self, s1, r, a):
        s1['actionlist'] = self.actionlist
        # 3- do forward pass for the next state
        with torch.no_grad():
            self.Q1 = self.target_qnet(torch.from_numpy(featurize(s1)).float().to(device))

        # 4- set Q-target
        q_target = self.Q.clone()
        #Update value of the current action
        q_target[a] = r + self.gamma * self.Q1.max().item() * (not done)

        # 5- update network weights
        loss = self.qnet.loss(self.Q, q_target)
        loss.backward(retain_graph=True)
        self.qnet.optimizer.step()
        self.target_qnet.update_params(self.qnet.state_dict(), self.tau)

        return loss

# %%
# Pommerman agents setup
# Own agent ready to play against 2 simple and 1 random agent
agents = {}

agent_id=0; agents[agent_id] = SimpleAgent(config["agent"](agent_id, config["game_type"]))
agent_id=1; agents[agent_id] = SimpleAgent(config["agent"](agent_id, config["game_type"]))  
agent_id=2; agents[agent_id] = RandomAgent(config["agent"](agent_id, config["game_type"])) 
agent_id=3; agents[agent_id] = OwnAgent(config["agent"](agent_id, config["game_type"]))

env.set_agents(list(agents.values()))
env.set_init_game_state(None)

# %%
class RewardsShaper:
    """Implementation of our defined reward shapping"""
    def __init__(self):
        self.bomb_list = {'own_bombs':{},'other_bombs':{}}
        

    def run(self, s, a, s1, done, info):
        reward = 0
        lookup = ['Stop', 'Up', 'Down', 'Left', 'Right', 'Bomb']
        
        a = a[3]
        
        p  = s[3]['position']
        p1 = s1[3]['position']
        o1 = s[0]['position']
        o2 = s[1]['position']
        o3 = s[2]['position']
        
        # Update bomb_list
        if(a == 5 and s1[3]['bomb_life'][ p[0] ][ p[1] ] == 9):
          
          self.bomb_list['own_bombs'][str(p[0])+","+str(p[1])] = {
              'position': [ p[0], p[1] ],
              'strength': s[3]['blast_strength']
          }

        suicide = False;
        killer = 0
        chopTree = 0
        
        # Check if own bomb goes off
        for key, value in self.bomb_list['own_bombs'].items():
          b = (value['position'][0], value['position'][1])
          if(s[3]['bomb_life'][ b[0] ][ b[1] ] == 1): # Own bombs goes off at bomb_life = 1
            
            fire_list = []
            blast_strength = self.bomb_list['own_bombs'][key]['strength']
            
            fire_list.append(b)
            for i in range(1,blast_strength):  
              if (b[0] - i >= 0):
                if (s1[3]['board'][ b[0]-i ][ b[1] ] == 4):
                    fire_list.append( (b[0]-i, b[1]) )
              
              if ( b[0] + i < 11):
                if (s1[3]['board'][ b[0]+i ][ b[1] ] == 4):
                    fire_list.append( (b[0]+i, b[1]) )
              
              if (b[1] - i >= 0):
                if (s1[3]['board'][ b[0] ][ b[1]-i ] == 4):
                    fire_list.append( (b[0], b[1]-i) )
              
              if (b[1] + i < 11):
                if (s1[3]['board'][ b[0] ][ b[1]+i ] == 4):
                    fire_list.append( (b[0], b[1]+i) )
            
                                 
            del self.bomb_list['own_bombs'][key]
            
            if(p1 in fire_list):
                suicide = True
            
            if(o1 in fire_list):
              killer += 1
              
            if(o2 in fire_list):
              killer += 1
              
            if(o3 in fire_list):
              killer += 1
            
            
            for pos in fire_list:
              if(s[3]['board'][pos] == 2):
                chopTree += 1
                
            break

        # Reward: Lay bombs and have ammo
        if(a == 5 and s[3]["ammo"]>0):
            reward += 0.1
            
        # Penalty: Lay bombs and have no ammo
        elif(a == 5 and s[3]["ammo"]==0):
            reward -= 0.1

        # Penalty: Go into fire! or stone, wood or off the board
        y, x = s[3]["position"]

        if(a==3): # action is go left
          if(p[1]-1>=0): # is on the board
            next_pos = s[3]['board'][ p[0] ][ p[1]-1 ]
            if(next_pos == 4): # fire
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # on not the board
            reward -= 0.1

        elif(a==4): # action is go right
          if(p[1]+1<11): # is on the board
            next_pos = s[3]['board'][ p[0] ][ p[1]+1 ]
            if(next_pos == 4): # and fire to the right
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # not the board
            reward -= 0.1
            
        elif(a==2): # action is go down
          if(p[0]-1>=0): # is on the board
            next_pos = s[3]['board'][ p[0]-1 ][ p[1] ]
            if(next_pos == 4): # and fire under
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # not the board
            reward -= 0.1

        elif(a==1): # action is go up
          if(p[0]+1<11): # is on the board
            next_pos = s[3]['board'][ p[0]+1 ][ p[1] ]
            if(next_pos == 4): # and fire over
              reward -= 1
            elif(next_pos == 1 or next_pos == 2): # stone or wood
              reward -= 0.1
          else: # not the board
            reward -= 0.1

        # Penalty: Don't stand still for more than 10 turns
        index = 0
        counter = 0
        for i in range(len(ep_actions)):
          counter+=1
          if(ep_actions[-counter])!=0:
            counter-=1
            break
        
        if(counter>9):
          reward += (9-counter)
          
        # reward: picking up powerups!
        powerup = 0
        if (s1[3]['blast_strength'] > s[3]['blast_strength']):## incr range
          powerup += 1
          
        if (s[3]['board'][ p1 ] == 6): ## extra bomb
          powerup += 1
        
        if (s[3]['can_kick'] == False and s1[3]['can_kick'] == True):  ## can kick
          powerup += 1
        
        
        reward += 4*powerup
        reward += -3*suicide
        reward += 10*killer
        reward += 2*chopTree
        
        return reward, suicide

# %% [markdown]
# # Load model file
#
# It is possible to load previous trainned models.

# %%
#from google.colab import files
#import io
#uploaded = files.upload()

# %%
#buffer = io.BytesIO(uploaded["simple_modelB.pth.tar"])
#agents[3].qnet.load_state_dict(torch.load(buffer))

# %% [markdown]
# # START TRAINING
#
# Train our own agent

# %%
# train Q-network
# %%time

env.seed(0)

num_episodes = 20000
episode_limit = 1000
val_freq = 100 # validation frequency

try:
    epsilon = 1.0
    shapedreward = RewardsShaper()
    rewards, lengths, losses, epsilons, wins, actionlog = [], [], [], [], [], []
    print('start training')
    for i in range(num_episodes):
        # Init new episode
        s, ep_reward, ep_loss, suicide, ep_actions = env.reset(), 0, 0, 0, []
        q_values = []
        r = 0
        
        # Maximum rounds per episode
        for j in range(episode_limit):
            actions = env.act(s)
            s1, r, done, info = env.step(actions)
            
            #Check if our agent is still alive
            if(13 in s[3]['alive']):
                ep_actions.append(actions[3])
                
                shaped, suicide = shapedreward.run(s, actions, s1, done, info)
                ep_reward += shaped
                r[3] += shaped
                loss = agents[3].afterstep(s1[3], r[3], actions[3])

                ep_loss += loss.item()
                q_values.append(agents[3].Q)
            else:
              done = True
               
            s = copy.deepcopy(s1)
            if done: break
              
        # Episode is finished
        if(suicide>0):
          print("s",end="")
          wins.append(0)
        elif("winners" in info):
          if(3 in info["winners"]):
            ep_reward += 1
            wins.append(1)
            print("W",end="")
          else:
            ep_reward -= 1
            wins.append(0)
            print(".",end="")
        else:
            ep_reward -= 1
            wins.append(0)
            print(".",end="")
        
        # Bookkeeping
        epsilon *= num_episodes/(i/(num_episodes/20)+num_episodes) # decrease epsilon
        epsilons.append(epsilon); rewards.append(ep_reward); lengths.append(len(ep_actions))
        losses.append(ep_loss); actionlog.append(ep_actions)
        if (i+1) % val_freq == 0: print('{:5d} mean training reward: {:5.2f}'.format(i+1, np.mean(rewards[-val_freq:])))
    print('done')
except KeyboardInterrupt:
    print('interrupt')
# Out:
# start training
# .ssss.ssss.ssssssss.ss.sssssss.s.ssssssssssssssssss.sssssss.ss.sss.s.sssssssssssss.sssssssssssssssss  100 mean training reward: -1.34
# ss.ssssss.sssssssssssss.s.sssss.sssssss.ssss.sssss.sssss.s.ssssss.sss..ssssssssssssssssssss.sss.s..s  200 mean training reward: -1.69
# ssssssssss..ssssss.ssss.sss.sssss.ss.s.sssssss.ssssss.sssssssss.s.s.ss..sssss.ss.s..ss.ssssssss.ss.s  300 mean training reward: -0.69
# sssss.ssssssss.sssssss.ssssssss.ssss.ssssss.s.sssssssssss.ss.sssssssss..ssssss.ssssssss.s.sssss.s..s  400 mean training reward: -1.05
# .ssss.ssss.sss.ssssssss.ssss.s.s.ssssss.sssss.s..sssssssssss.ss.sssssss..ssssss.ssssssssssssssssssss  500 mean training reward: -1.26
# s.s.ssssss.sss.ss.s.ss..sssssss.ss.sss.ssssssss..ssssssssssssssssssssssssssssss.sssssssss.ssssss.sss  600 mean training reward: -1.71
# s...ssssssssssssssss.s.sss..ss.ssssss.sssssss.sssssssssssss.Wsssssssssssssssssssssss..s.sss.ssssssss  700 mean training reward: -1.30
# sss.sssssssss.s.ss..ssss.ssss.ss..sssssssssss.sssss.s.ssssssss.ssssss..s.s..sss.sssssssssss.ssssssss  800 mean training reward: -1.13
# ssss.ssss.sssss..s.ssss.ssssssssss.s.ss.ss...s.ss.sssss.ssssss.ssssssss.sss.s.s.s.ssssssssssssssssss  900 mean training reward: -0.94
# s.s.ssss.sss..sssssss.ssssssss.ssssss.ssssss..ssssssss.sssssssss.s.ssssssssssssssss.s.ssssssssssssss 1000 mean training reward: -1.13
# ..ss.s.sssssssssss.sssssssss.ssssssssss.s.s.s...sss.s.ssssssss..s.s.ssss..sss.sssssssss.ssssssssssss 1100 mean training reward: -1.09
# ssssss.s.sssss.sss.ssss.sssssss.s...sss.ssssssss....s.sssss.s.ssssssss.ssssss.sss..ss.s..ss..sss..ss 1200 mean training reward: -0.82
# sssssssss.sssssssss..ssssssss.ssssssssssssss.s.s.s.ssssss..s.ss.ssssssss.s.s.ssssssssss..ss.s.s...ss 1300 mean training reward: -1.31
# ss.s.ssss..ssssss.sssssssssss.sssssssssssss.ssssss..ssss.ss.sssss.sssssssss.sssss.sssssssss.ssssssss 1400 mean training reward: -0.80
# sssssssssssssss.ss.ssssssssssssssssssssss.sss.ss.sssssssss.ssssssssssss.s..sss.sssssssssssss.ss.ssss 1500 mean training reward: -1.61
# .s.ss.s.ss.ssssssss.ssssssssss...ss.sss.ssssssssssssssssssss.sssss..sssss.ss.ss.sss.sssssssss.ss.sss 1600 mean training reward: -1.11
# ssss.s..ssssssssssssssssssss.s.ssssssssssss.sssssssss.sssssssssssssss.s...ss.sss.ss.ss.sss.sssss.sss 1700 mean training reward: -1.26
# sss...s.sssssssssss.ssss.sss.ss.ssssssssssss.ssssssssss.ssssssss.sssssssss.ssssssssssss.ssssssss.sss 1800 mean training reward: -0.97
# ssssssssss.s.sssssssssssssss.ss.ss.sss.s.sssssss.s.ssssssssssssss.ssss.ss.ssss.ssssssss.sssssss.s..s 1900 mean training reward: -1.17
# sssssss.sssssssssssssssssssssssssssss.sssssssssssWss.sssssss.ss.ssssssssssssssssssss.ss.ss..ssssssss 2000 mean training reward: -1.40
# sssssssss....s.s.sssssssss.sssss.ssss..sss.s.sssssssssss..ssssssssssss.ssssssssssss.sssss.sssssss.ss 2100 mean training reward: -1.15
# sssss.sss..ssssssssss.ss.sss..s.sss.s.sssssss..sss.s.ss.ss.sss.sss..ssssssss.s.ss..ss.ss.ss.s...ssss 2200 mean training reward: -1.02
# sss.sss.sssssss.ss.sssss.ssss.sssss..ssssssss.ss.ss.sssssssssss...sssss.ss.s.s.sss.sssssss.s.ssss.ss 2300 mean training reward: -0.79
# ssssssssss.sssss.sssssssssssssssss.sss.ssssss.ssssssssss.sssssssssssss.ss..ss.sssssss.s.ssssssssssss 2400 mean training reward: -1.37
# ss.s.ssssssss....ssssWsssss.sssss.sssssssssssssssss.sssss.sss.ssss.ss.ssss..ssss.s.ssss.ssss.sssssss 2500 mean training reward: -0.86
# ssssssss..sss..ssssssssssssss.s.ssssssssss.sssss.ssssssssssssssssssssssssssss.sssssssss.sssssss.ss.s 2600 mean training reward: -1.82
# ssssssssssssssss...ssss.sssssssssss.sssssssssssss.s..sss..sss.ssss.s.ssssssssssss.s.sssss..sss..ss.s 2700 mean training reward: -1.55
# ss.sssssssssss...s.sss.ssssssss.sss.ss.sss.ss.sss.sssssss.ssss.sssss.ssssssssssssssssssss..sssssssss 2800 mean training reward: -1.24
# sss.sss.sssssss.s.ss.s.ss.sssssssssssssssss.sssss.ssssss.s.sss.ssss.s.ssss...sssss..sssss.sss.ssssss 2900 mean training reward: -1.10
# .sss.s.s.sWsssss.s.s.ssssssssssssssssss.sss.sssssssss..ssssssssssssssssssss.sssssssssss.ssssssss.s.s 3000 mean training reward: -1.44
# sss.ssssssss.s..sssssss.ss.ssss.sssssssssss.sW.ss.s.ssss..ssss.s.sss...sssssssssssssssssssssssss.sss 3100 mean training reward: -1.32
# ss.ss.s.ssssssssssssssss.sssssssssssssss.s.ssssssssss.ss.s.sssss.sss.sssssssssssssssssssssss.sssss.s 3200 mean training reward: -1.10
# s.sss.s.ssssss.sssssss.ssssssss.sssssss.ssssss.ss.sss.ssssssssssssssssssss.sssssssssss..s..ssssssss. 3300 mean training reward: -1.31
# sss..sssssss.sssss.sssssssssss.ssssssssssssssssssssssssssss.sssss.ss.sssssssssssssssssssssssss..sss. 3400 mean training reward: -1.41
# sss.ssss.ss.ssssss.sssssss.sssssssssss.sssss.s.sssss.sssssss.ss.s..sssssssssssssssssssss.sssssss.sss 3500 mean training reward: -1.08
# s..sssss..sss..sssssssssss.ssss..ssssssssss..sss.sssssssssss.ssssssssss.sssssss.ssss.s.sssssssss.sss 3600 mean training reward: -1.09
# .s.ssssssss.ssssss..sssssssss.sssssssssssssss..ss.ssssss.ssssssssssssssssssssssssssssssssssss.ssssss 3700 mean training reward: -1.22
# ssssssssssss.sssssss..sss.ssssssssss.s.sssssssss.ss.sssssss.ss.ssssssssss.ssssssssssssssssssssssssss 3800 mean training reward: -1.49
# ssssssssssss.sssssssss.sssssssssss.s.s.s.ssss.s.sssssssssssssssssssssssssssssssssss.ssssssssssssss.. 3900 mean training reward: -1.46
# sssssssssssssssssss.sss.ssssssssssssssssssss.ssss.ssssssss.ssssssss.sss.ss.s.ssssssss.s.ss.s.sssssss 4000 mean training reward: -1.28
# s.ss..sssss..ssssssss.sss.ss.ssss.sss.s.sss.sssss.sssss.s.ssssss.ss.sssssssssssss.ssssssss.s.sss..ss 4100 mean training reward: -1.11
# ssssssss..ssss.s.ssss.ssssssss.ssssss...sssssss.sssss.s.sssssssssss.ssssssssssssss.sssssssssssssssss 4200 mean training reward: -1.00
# ss.sss.s.sss.sssss.sssss.ssss.ssssssss.ss.s.sssss.sssssssssssssssssssss.sssss.sssssss.ssss.sssssssss 4300 mean training reward: -1.03
# ssssss.sssssssssssssss.ssssssss.ssssssss.sssssssssss.ssss.sssssssssssssss.ssssssssssssssssssss.sssss 4400 mean training reward: -1.53
# ssssssssssss.ssssssssssss.ssssssssss.sssssssss.sssssssss.ss.s.sssss..ssssssss.s.sss.sss.ssss.sssssss 4500 mean training reward: -1.27
# sssssssss.ss...sssssssssssss.s.sssssssssss.sssss.ssssssssssssss.ss.s.ss.sssss.sssssssssss.ss.sssssss 4600 mean training reward: -0.97
# ssss.ssssss.sssss.s.sssssssssssssssss.s.ss.ssssss..s.sssssssssss.sssss.sss.s.sss..ss.sssssssssssssss 4700 mean training reward: -1.20
# ssss.s.sssssss.ssssss.ssssssss.ssss...ssss.sssss.s.ssss.s.s.ssss.ssssss.sss...ssss.ssss.sssssssssss. 4800 mean training reward: -0.83
# sssssss.sssssssssssssssssssss.sssssssss.s.ssssss.ss.sss.sssss.sss.s.sssss..ss.sssssssss.s.ssssssssss 4900 mean training reward: -1.56
# .ssssssssssssssssssssssss.sssssssssssss.sssssssssss.ssssssss.ssssssssssssss.ss.sssssssssssssssssssss 5000 mean training reward: -1.32
# sssssssssssssssssssss.sssssssssss.ssssss.s..ssssssssssssssssssssssssssss.sssssssssssssss.sss.ss.ssss 5100 mean training reward: -0.89
# ss..ssssss.sssssssssssssss.s.s.ss.ss.ssssssssssssssssssssssssssssss.ss.ssssssssssssssss.ssssssssssss 5200 mean training reward: -1.46
# .ssssssssss.ssssssssssssssss.sss.sssssssss.sss.ssssssss.s.sssss..sssssssssssssssssssssssssssssssssss 5300 mean training reward: -1.01
# sssssssssss.sssss.ssss.sssssssssssssssssssssssssss.ssssssssssss.ssssssssssssssssssssssss.ssssss.ssss 5400 mean training reward: -1.46
# ssssssssssssssssss.sssssssssss.ssssssss.sss.sssss.sssssssssssss.s.sss.sssssssssssssssssssssss.ssssss 5500 mean training reward: -1.03
# ssssssssssssssssss.sssss.sss.sssssssssss.sssssss.sss.ssssssssssssssssssssssssss.sssssssssssssss.ssss 5600 mean training reward: -1.30
# sssssssssssssssssssssss.sssssssssssssssssss.ssssssssss.ssssss.sssssssssWs.ssss.ss.ssssss.sssssssssss 5700 mean training reward: -1.53
# ssss.sssssssssssssssss.ssssssss.s.ssssssssssssssss.ssssssssssssssssss.ssss.sssssssssssss..ss.sssssss 5800 mean training reward: -1.44
# ssssssssssssssssssss.ssssss.sssssssssssssss.ssssssssssssssssssssssssssssss.ssssssssssss.sss.ss.ssss. 5900 mean training reward: -1.32
# .sssssss.ssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssss.ss..ssss.sssss 6000 mean training reward: -1.83
# .sssssssssssssssssss.sssssssss.ssss.ssssssssssssssssssssssssssssssssssss.sssssssssssssssssssss.ss.ss 6100 mean training reward: -1.56
# sssssss..ssssssssssssssssss..sssss.ss.s.sssssssss.ssssssssssssssssssssss.ssss.ssssssssssssssssssssss 6200 mean training reward: -1.33
# sssss.ss.sssssssssssssss.ssss.ssssssssssssss.s.sssssssssssssssssssssssssssssss.sssssssssssssssssssss 6300 mean training reward: -1.45
# sssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssssssssssssss.ssssssss.ssss.sssss 6400 mean training reward: -1.46
# ssss.sssssssssss.sssssssss.sssssssssssssssssssssssssssssssssssssssssssssssss.sss.s.ssssss...sssss.ss 6500 mean training reward: -1.06
# ssssssssssssssssssssss.ssss.sssss.ssssss.sssssss.ssssss.sssssssss..sssssssssssssssssss.sssssssssss.s 6600 mean training reward: -1.26
# ss.sssss..ssss.ssssssss.ssssssss.sssssssssssssss.sssssssssssssssssssssssssssssssssssssssssss.sss.sss 6700 mean training reward: -1.19
# sssssssssss.ssssss.sssssssssss.sssssssss.sssss..ssssssssssssssssssss..ss.ssssss.ssssss.sssss.sssssss 6800 mean training reward: -1.29
# ssss.sssssssssssss.ssssssssssssssssss..s.ss.ssssssssss.ssssssssssssssssssssssssssssssss.ssssssssssss 6900 mean training reward: -1.22
# .ssssssssssssssssssssssssssssssssssssssssssssssssssssss.ssssssss.s...ssssssss..ssss.ssssss.sss.sssss 7000 mean training reward: -0.97
# sss..ssssss.ssss.s.s.ss.ssssssssssssssssssssss.ss.sssssssssssss.sssssss.sssssssssssssss.sssss.ssssss 7100 mean training reward: -0.72
# sssssssssssssssssss.sssssssssssssssssssssssssssss.ssssss.ssssssss.ssssss.sssssssssssssssssssssssssss 7200 mean training reward: -1.11
# sssssss.ssssssssssssssss.ss.ssssssssssssss.ssssssssssssssssssssssssss.ssssssss.ssssssssss.sss.ssssss 7300 mean training reward: -1.00
# sssssssssssssssss.ssssss.sss..ssssssssssssssssssssssssssss.sssss.s.s.ssssssssssssssss.ssssssssssssss 7400 mean training reward: -1.20
# .sssssss.ss.ssssssssssssssssss.sssssss.sssss.sssssssssssssssssssssssssssssssssssssssssssssss.sssssss 7500 mean training reward: -1.40
# ssssssssssssssssss.sssssss.s.sssss.ssssssssssssssssssss.ssssssss.s.ssssss.s.sss..ssssssssssss.ssssss 7600 mean training reward: -0.75
# ssssssssssssss.ssssssssssssssss.ssssssss.sssssssssssssssss.sss.sssssssssssssss.sssssssssss.ss.ssssss 7700 mean training reward: -1.21
# ssssssssss.sss.ssssssssssss.ssss.sssssssssssssssss.sssss.ssss.sssssssssssssssssssssssssssssss.ssssss 7800 mean training reward: -1.07
# ssssss.sssssssssssssss.s.s..sssssssssssssss.sssssssssssss.sssssssssssssss.sssssssssss.ssssssssssssss 7900 mean training reward: -1.07
# ssss.sssssssss.ss.ssssssssssssss.ss.ss.ssss.ssssssssssssss.sssssss.ssssssssss.s.sssssss..sssss..ssss 8000 mean training reward: -0.91
# ssssssss.sssssssssssssssssssss.s.s.ssssssssssssssssssssssssssssssssssss..sssssssssssssss..ssssssssss 8100 mean training reward: -1.16
# .ssssss.ssssssssssss.sssssssssssssssssssssssssssssssssssssss.ssssssssssssss.sssss.ssssssssss..ssssss 8200 mean training reward: -1.45
# ssssss.sssss..sssssss.sssssssssssssssssssssssssss.ssssssssssssssssssssss.sssss.ssssssssss.s.sss.ssss 8300 mean training reward: -1.35
# sssssss.ssssssssss.ss.sssssssssss.ssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssssssssss 8400 mean training reward: -0.96
# s.ssssssss.ssssssssssssss.ssssssssss.s.sssssssssss.s.ssssssss.sssssssssssssss.ssss.sssssssss.sssssss 8500 mean training reward: -1.73
# ssssssss..sss.sssss.ssssssssss.sss.sssssss.ssssssssssssssssssssWssssssssssssssssssssssssssss.sssssss 8600 mean training reward: -1.78
# ssssss.sss.sssssssssssssssssssssss.ss.ss.ssssssssss.sssssssssssss.ssssssssssssssssssssssssssssssssss 8700 mean training reward: -1.76
# sssssssssssssssssssssssssssssssssWssssss..s.ssssssssWsssssssssssssssssssssssssssssssssssss.ss.sss.sW 8800 mean training reward: -1.91
# sssss.ssssssssssssssssssss.ssssssssssssssssss.ss.sssssssssssssssssssssssssssssss.s.sssssssssssssssss 8900 mean training reward: -1.78
# ssssss.sssssssssssssssssssssss.sssssss...ssssssssssssssss..ssssss.ssssssssssssssssssssssssssssssssss 9000 mean training reward: -1.19
# Wss.ssssss.s.ssss.ssss.ssssssss.sssss.ssssssssssssssssssssssssssssssss.sssssssssssssssssssssssssssss 9100 mean training reward: -1.45
# sssssssss.sssssssss.ssssssssss.ssssssssssssssssssssssssssssssssssssssssssssssssssss.sssssss.ssssss.s 9200 mean training reward: -1.94
# ssss.ssssssss.sssssssssss..sss.ssssssssssssss.sss.ssssssssssssssssssssssssssssssssssssssss.sssssssss 9300 mean training reward: -1.69
# sssssssssssssssssssssssssssssssssssss.sssss.ssssssssssssss.sssss.sssssssssssssssssss.sssssssssssssss 9400 mean training reward: -1.56
# ssssssssssssss.ssssssssssssssssssssssssssssssssssssssssss.ssssssssssssssssssWssssss.sss.ssssss..ssss 9500 mean training reward: -1.23
# ssss.ssssssssssssss.ssssssss..s.s..sssssss.sssssssssssss.sssssssssss.ssssssss.sssssssssssssssss.ssss 9600 mean training reward: -1.18
# ssssssssssssssssssssssssssssss.ss..ss....ss.ssssssssssssssssssssssssssssssssssssssssss.sssssssssssss 9700 mean training reward: -1.17
# ssssssssssss.ssssssssssssssssssssssss.sssssss.ssssssssssssssssss...sssssssssss.ssssssssssssssss.ssss 9800 mean training reward: -1.72
# sssssssssssssssssssss.ssssssss.s.sss.s..ssssssss..ssssssssssssss.ssssssssssssss.ssssss.sssss.ssssss. 9900 mean training reward: -1.08
# .sssssssssssssssssssssssssss.sssssssssssssssssssssssssssssssss.ssssssssss.s.s.ssssssssssssssssssssss10000 mean training reward: -0.97
# ssssWssss.sssss.ssssssssssssssssssssssss.ss.sssssssssssssssssssssssssss.ss.ssss.ssssssssss.sssssssss10100 mean training reward: -1.38
# sssssssssssssssssssssssssssssssssssssssssssssssss.sssss.ssssssss.ssssssssssssssss.sss...ssssssss.sss10200 mean training reward: -1.72
# sssssssss..sssssssssssssssssss.s..sssssssss.ssss.ssssssss.sssssssssss.ssss.s...ss.sssssssss.ssssssss10300 mean training reward: -1.92
# ssssssssssssssssssss.ssss.sssssssssss.s.ssssssssssssssss.sssssssssssssWss.ssssssssssss..sss.sssss.ss10400 mean training reward: -0.76
# sssssss.sss.s.sssssssssssssssssssssssss.ssssssss.ssssssssssssssssss.sssss.ss.sssssssssssss.ssssss.ss10500 mean training reward: -1.21
# ss.sssssssssss.sssssssssssssssssssssss.sss.sssss.s...sssssssssssssssssssssssssssssss.sssssssssssssss10600 mean training reward: -1.02
# sssssssssssssssssssssssss.sssssssssssssss.sssssssssssssssssssssssssssssssssssssssssssssss.ssssssssss10700 mean training reward: -1.02
# sW..ssssssssssssssssssssss.s........sssssssssssss.ssss.sssssssssssssss.s.sssssssssssssssssssssssssss10800 mean training reward: -1.96
# ssssss.sssssssssssssssssssssss.ssss.ssss.sssss..ss.sssssssssssssssssssWsssssss.ssss.ssssss.ssss...ss10900 mean training reward: -1.44
# sssss.sssssss.ss.WssssssssssssssssssssWs.sssssss.ssssssWsssssss.sssssssssssssss.sss.ss..sssssss.sss.11000 mean training reward: -1.41
# ssssssssssssssss.sssssssssss.ss.ssss.sss.sssssss.ssss.sssssssss.s.s.ssssssssssssssssssss.ssss.ss.sss11100 mean training reward: -1.10
# sss.ssssssssssssss.ssssssss.sssssss.ssssssss.sssss.ssssssssssssssssssss.....s.ssssss.sWsssssWss.s...11200 mean training reward: -3.12
# ssssssssss..s.s..s.sssssssssssssssssssssssssssssssss.sss..sss.ssss.sss........s.sssssss.ss.ssss.ssss11300 mean training reward: -3.04
# ssssss.s..s.W.sssssW.s...ssss...Ws...sss.ss.sss..sss.sssWss..ss..s.s...ss...Ws.........s..s...s.sssW11400 mean training reward: -1.78
# s.ss.s..s..W......ss....s..s..W.ss.ss...s..s..ss.s.s..ss.sssss.s.sss....sss.sss.sssss.ssss..sss.ssss11500 mean training reward:  1.60
# ..s.sssssW...sssss...ssss.ss.s..sss..ss.ss...sssss...s.ss...ss.ss..ss.ss.s.ssssss.sss.ssss.ssssssss.11600 mean training reward:  3.07
# ssss.ss..ssssssssss.s.sss....sssss.s..s..s.sss.sWs.ssssss.ss..sssss.s.sssss..ssss.s.ssss..sssssssss.11700 mean training reward:  1.78
# ssssWs.s.ssssssss.ssssssssssssssssssssssss..s.s.ss.sssss....s.sss..ss.ss..sss.sss..ssWss.s..sssW..s.11800 mean training reward:  2.46
# s.ss..ssssss.sss.ss.s..sssss..s..sWW.ssss.sW.ss.s.sss.ss.ss.ssssss.ssss....sssss.ss.ss.sss.ss.W.Ws.s11900 mean training reward:  1.37
# ss.ssss.sss.s..s.ss.ss...ss.ss.s.s.ss.s..ssss..ss..s.ss..s.s.s..s.ss.Ws.ssss...ssssss....s..ssssssss12000 mean training reward:  1.93
# .s.s.Wsssss.ssW.ss......s.s.s.sWWs..ss...ss..sss.ss.....ssssssW....ss..ss..s.s.s.s.s.....s..ss.ss.ss12100 mean training reward:  1.82
# s.s.ss.W.ssWssss..sWssssss.s..s..s....s.ss.Wss..s.W.s...s..s.ss.ss.s.s..s.ss....ss.s.sss..ssssss..s.12200 mean training reward:  2.95
# sss.ss.s.ss...s...ss......sss.s..sW.....sW.sss.sss.s.sss.s.W....sW.s.s.sWsWs...ssss.Wss.sss.ss.s.sss12300 mean training reward:  2.87
# s.sWW.sWs.s.s..ssss.ss.sssWss..ss.W....ss.s....s.s.s..sss..sssss.sWsss..s.ss.s...ss.ss.ssWssss.sssss12400 mean training reward:  3.02
# ..sss.s.ssssssWss.s.ss.ss.sss.sss.s.sss...s..sWsss.ss..ss..sW...s..s.s.ss..s.ss..s.ss.sss..s.s.s..ss12500 mean training reward:  2.40
# Ws..sssssss..ssss..ssss...sssW..W.sss.sss.ss.s..sW..sssss.ss..s...s..sss.......WsW.....s..ss.s.ssss.12600 mean training reward:  2.76
# .s..ssssWss.s...ss...ss..ss.s.s......ss.W.sss....s.s.Wss...Ws..sW..s.Ws..s.s...ss..sWs..ss.W.ss..s.s12700 mean training reward:  3.43
# s....ss....sss...ss.s.s...s.WsWWss..W.WsssssssW....sss.s.s.ss.ssss...ss..ss..sWss...s..s.....W.s.sss12800 mean training reward:  2.28
# .s.sss.ss........s.ssssssW.....sss.ss..sssW.s...W.s..W..ss.sss...WWs.sssss....s...s..ssss.s..s....s.12900 mean training reward:  2.81
# ..sWs.ss.ss...s.W.sss.s.s.s....s.ss.W.s....s..ssss..s..ss.s.....ss..s.WssWW.ss......s..ssss..s..sss.13000 mean training reward:  3.27
# s..s.ss.s.s..sWs.ss.sss.sW.s.sssssss.ssssss.ssssssW.s.ss.sssss.s.sssss.s..W..s.W.s.W...s.s.s..sW.s..13100 mean training reward:  3.61
# s.sWss.s.ssWssss.s.s.s.s.ss...sWs.s....sW.........s..W..W.ssW.s.sW.s.........W.s...ss..ssssss..ss.W.13200 mean training reward:  2.83
# .sW...sss...........W.....s...sss.W..W...ss.....Wssss..s.sss..s...s....W.....ss.s...s..s.s.s.W..W.ss13300 mean training reward:  2.47
# .....ss.s.s.sW..s....ssss.W...s..s..W.s.s......s.......s..........s.s..Wsss..s.ss.W.W...........W...13400 mean training reward:  1.90
# .W.WWWWW.W......Ws.sssss.s.....Ws..s...sW.ss.W..s..Ws.ss...s..sss...s...ss.sss...s.sWs.ss.ss...Wss..13500 mean training reward:  1.78
# ss.s.ssss..s.sWs...s...s....s.s.........s.Ws....W.s..sWss....W.Ws..s..ss........Wss.......s.....sss.13600 mean training reward:  2.83
# ..sW.sW.sss.s.s..W..s.W...s.s.ss...ss.ssss......sssssW...Ws.WssWs...s...s...ss.s.ss.s...ss....W..W.s13700 mean training reward:  2.28
# ..W..s.ss....s.s..sss.s..s..ss.Ws.......ss.s.s.s.W.s.s.....W..WW.s.......s.s.sss...s.sss.ss...ss.Ws.13800 mean training reward:  2.08
# .s...WsssW..s..ss.W..ss.W..s....W...s..sW.sssW.s.....ss..s..s.....s.s..ssW..ssss..sss..W.sWs...sW.ss13900 mean training reward:  3.14
# s.sss..ss.sss.sssssssssssss.sssss.sss...s..s.s.ssssssWs..s.sss.ssssss.s.ss...ssW.ss..ssWssWsss.s..ss14000 mean training reward:  3.37
# .sW.ss.W.ss.....s..ss...W....Ws........W...s.Ws...ss...ss.s...sss..s.s..ss..s.W.W.s.sss..s.sss.ssss.14100 mean training reward:  3.07
# ssss.s...sss.ssW..ss.ss.sWss.ssss..s.s.s.sss...sssssss.s.sWs.s..WssWss.s..sss....s..sW.s.W.ss.W...ss14200 mean training reward:  4.31
# .ss.sW...s..s......sW..s.ss..ss..s.W.....ss.s..s.W.W....WW.........s..sssss.Wssss....s.s..s.s...ssWs14300 mean training reward:  3.79
# .ss...s.s.Wssss.sss...ss.W.ss.sW.....sWssW......W..ssss.ss...W..s.s...s.W..W...s.W...W......W.......14400 mean training reward:  4.23
# .ssW...s......s.s..s...s.Ws.....s..Ws....W.ss...ss.sss.s..sW..W.........W........s..sssW.s.s......s.14500 mean training reward:  4.76
# ..s.s..W..sss.sssss.s.s.Ws...sWsss.ss..ss.sss.ss.sss.ssWs...W.s.s....s...W...s..sssss.s.WWs...s.WW..14600 mean training reward:  5.00
# ...Ws...s.Ws.s.sssssssss.ss.s...s.ss.ss..s.Ws.s.sWs.ss.s.s......s..ss.ss..s.....s.s..s.s...s....sss.14700 mean training reward:  3.66
# ..s..s..sssWssssss.ss..ssssss....ss.s..W.s...s.s.W.ssWssWs.s....s.sW.s..s.ss..s..s.ss...s..ss.sss..W14800 mean training reward:  5.41
# ....ss..sss...s.s.....s..sss....s.ssssssssssss.s.s...s.s.sss.....s...ss...W....ssWss.sss.....s.....s14900 mean training reward:  5.07
# ss.s.Wss.s.sss.s.....sssW...ss..ss...ssssssWsss.sW....Wsss.s.sss.WW....W..WW.......s..WW..........s.15000 mean training reward:  4.30
# s.s.sWW.......s.....s.........ss.....W..s.s...s.sss.s.sss.ssssss..ss.s.ssss..s...sssWs...W.....W....15100 mean training reward:  4.39
# .s.W.s.W.s..WW...Ws.ss.....ssWs.W....s........sWs..sssWss.sss....s.sss...........s..W.sWss......s.ss15200 mean training reward:  3.84
# s....s.ss...W....s...ss.sss....W....s.s.s.ss.s.s.....W.s.W.........s........s...s.....WW...sW.....s.15300 mean training reward:  4.02
# .ssW...ssWs..s..ss...Ws..s.ss.s..s...Ws..s............W...s....ss.W..s....s......ss.......ss....s.s.15400 mean training reward:  3.64
# .s..W.s......W...W.......Ws.sss..W..........s..W.sssWss..sWsssWW....s.ssss....s....W..s.W.s..WssW..s15500 mean training reward:  4.61
# .s..W....W..W...........s..s.ss.....sW..s...s.Ws..W..ss.........s...s..s.....W..Ws..W...W....WW.s..W15600 mean training reward:  4.04
# ....W.Ws.....sW..............s...Ws.....ss...s.ssss.s..s.s...s.WW.W....s.........Ws..WW.Ws.s..W.s...15700 mean training reward:  4.03
# .........s..ss....ss...ss.W...Ws.W.ssW...WW...W.s...s......s....W.............s....W..Ws........WWs.15800 mean training reward:  4.91
# ....Ws.......sW......ss.s.sss....Ws.s..sW.ss.s...ssW.s...sWs.sW...ss..s..WWW.ss.ss.sssW.s..ss....W..15900 mean training reward:  4.50
# .s.sss..W..s.......sss.sW.Ws.sWsss..ss.Ws..sWs..sssW...s.sssWss...s..s...ssss.s.....s.W.....s....sWs16000 mean training reward:  6.55
# .s....s.s.s......s.s..Ws..W..s....ss.s...sWsWs...s.ssss....s..s........ssssss.s...ss.s.s.sss..s.....16100 mean training reward:  4.80
# ..s.s.s.ssss..ss..sss.ssssWWW..s.sW....ss.sWss.s.s..sss.s...Wsss......sss.W....sWs.ss.sssssss...sWss16200 mean training reward:  5.48
# ..ss.Wss..ss..ssWss.s.ss...ssssWs.W..s..ss.......s.sWss.sWW.W.WsW......s.s..s...s.Wsss.ss..sss...W.W16300 mean training reward:  6.03
# .s....WW....W......s.........ss.....s..Ws......ss...........ss...s..........W.sss......s.s...W..s...16400 mean training reward:  3.92
# .....sW.s.s.Wsss...s.W..............s...s.s..s..W..s...ss..ss....s....sss.ss.....sWs.......W.W......16500 mean training reward:  5.41
# .........s.....WsWs.ss...sW.sssW.s..s......Wss..WWsWW.......ss.....ss........sWs.........sW.W.......16600 mean training reward:  6.82
# .....WssW......W..Ws......ss.W.s...W......W.sss..sssW.s...W..s.......W.sssW....W.Ws.........s..Ws...16700 mean training reward:  5.45
# .....s.s......ssssss..W........sW......W..s..s.....s....sW...s.....W..sW.s.sss.ssssss.ss..Wsss.s..ss16800 mean training reward:  6.26
# s..s.s.ss..sssWs.ss..ss.sss...s.sssss.....ssss.s...sWW...s.W.....s....Ws.s........ss...Ws.W.s.s.Ws.W16900 mean training reward:  6.15
# s...WWs...ss..s.s.....s..ssssssssss....s.s.ss.ss...s...sss.ssssssss.ss.ssssss.....s..s.sss...sss.ss.17000 mean training reward:  6.08
# ...Ws..ssWsss.ssssWssss....ssssssW..s.....s...s....s..ss..s..ss.s.ssss.sssssssss.....s..W.s....s..W.17100 mean training reward:  7.69
# WsWs.ssW...ss..sss.Wss...s.s.s..ssW.W...sss..sss..sWWs.sssss.ssss.ssss.ssss.ssssssssssss.ss.sssss...17200 mean training reward:  7.40
# s.s.s.s.s..ssss..s...ss..ssss.s..ssssss...ssssssss.ss...s..sss.sWs.sW..s..s.......s.ssssssWW.W..ss.s17300 mean training reward:  8.11
# sWs......s.sssssss..sssssW.ss.ss....ss.s.s.sssW....ss........s..s.s.......ss....s.ss.ss...Wssss.ssWs17400 mean training reward:  8.07
# sssss.s...ss..sssssss.sssss...ss.s..sWs..sss.sss.sss.....W....ss...ss.sss.s.ss.ssssss.s...s.sss.s.WW17500 mean training reward:  7.84
# .sssss....sss.ss..sss..s..ss.s...s..ss.....s..W...s...ss.s....ss.ss..s..ss.ss.ss....sss.s.....ss..s.17600 mean training reward:  8.29
# s.s.sss.ssssssss.sss..s..ss.s.ssss...ssssss.s.ssss....s..sss.ssss...ssss..sssss..s.s.s..ssss.sWs.ss.17700 mean training reward:  9.65
# s...W.ssss.ss.sss.ss.sss.ssss..s.W..s.s..s..s.ssss..WW.s...s.....ss....sW....s..s....sW..s..s.sss..s17800 mean training reward:  8.46
# .s..sWss...Wss.s..s..ss.s.s....s.s.Wss...Wsss..s.Ws..ssss.....s.ssss.s.sss.......s.s.Ws.ss.sss.s.s..17900 mean training reward:  9.48
# ..s.ss...ssss...ss..s....ss..s.s.......ssss.ssss.ssW....ss..W.....s.s.....s.s..ss.ss......s....WWW..18000 mean training reward:  9.25
# s.s......W.W...W...W..s....ss.W.sss.ss....s...sss...sssss.ssss.ssss.WsWsss...Wss.sss.ss.s...s..sssss18100 mean training reward:  9.86
# sss.ss.sssW.sss....sss.sss.s..ss....WW.....s.W....Ws.s.sW...W....s.ss.....W.s..s..W.sWs..WW.sW......18200 mean training reward:  8.59
# .sss..W.ss.s...s.....s.......W....s...s...s..sWs...s.ss...s.s.Wsss....s..Wss.ss...Ws.s...sss.s.s..s.18300 mean training reward:  9.15
# .sW.s.ss.s........s..W.sW......ss.s..........W.....ss.s..W.ss.s.s......sssss.ss.s.ssWs.s..Wss..ss.s.18400 mean training reward:  9.02
# s.Wss.s.ss..s.sssss.ssssss..sW...sss.ss....s.s..sss....ss..W..ssss..ssss.s..s...ss....ss..sss...sss.18500 mean training reward:  9.06
# .s.....s....ss.s.ss....s..sW....Ws..ssss.....s.s.s.s..ss.sss.sss.s.sW.ssssWs....ssss.sss..sss.ssssss18600 mean training reward: 10.27
# s...sWss.s.s.Wsss.sssW.s.W...sW....s....ss.....ssssWsss.s...s...ss..s..s.ss.sW.s...s.......s.s.ss..s18700 mean training reward:  9.74
# .Ws..s.sss.ss..ss.s..Wss..sssW.sssssW..sss.ss...s..Ws.W.s.W....s.ss...sss.s.s.s..sssssss....sssss.s.18800 mean training reward:  9.61
# .Ws.ss...s.s.sss.s...sssssssssss..s.sssssssssss.s.s..sWss....s..sss.s...Ws..ss.ss.Ws.s..W.........s.18900 mean training reward:  9.25
# .....sW....s..ss..s.WsWs....s.ssss................s.s.W.ss.s..W.s..s..W.W.ssssss.sssssssssssss.s...W19000 mean training reward:  6.61
# WssWss...s...s.s.........W.s...ssWs.WsssssWs.s..s..W..s..ssW.s..s.s.s....W.s.W.Wss......ss..s.ssW.s.19100 mean training reward:  8.97
# ..s..s.s..s.Ws.s.....s...Ws.s.s.s..Wss...ss...Wssss.sssss.sssWsW..ss.s......s...s.ss..sW.ss......W.s19200 mean training reward: 11.27
# .sss.s.s......sss....sWs..Wss..sssW..s..sss........s.ss.s..ss.....s...s.s.sW.....sW.....sss.sssss..s19300 mean training reward: 10.50
# ss....W.s.sW.WWs..sW.ssssss.sss...ss....W.s.........s..W.....W..s.......s....s.s.W..ss....s.....s.sW19400 mean training reward: 10.89
# ....s.....Wss..sssss..ssss.....s.s...s.s....s..s.W...s.s..ssss..s.s..ss..s..s..ss....W.....W..W..W..19500 mean training reward: 10.51
# sW...s......ss...W.....s......s.....ss....W..ssW.Ws.s.....s..s.....s....WWsWs.........s.s..Ws.ss...W19600 mean training reward: 10.14
# s.s.sWW..s.ssW...W.s...s...s.sss........W.WWW..s............s.....W...ssss.sW..s.s..WW.s.W.W....W.s.19700 mean training reward:  9.22
# ..ss....s.....W...W..s....ss....s.s..sss.sW.ss.....sss...ss..s..sW..........sW.......s.s.W..WW..s...19800 mean training reward:  9.61
# .sWs....WsW...s....W.......s....W........s.ssWW...s........s.s...s.ssssss..W..ssss..s.s.........W.s.19900 mean training reward: 11.16
# .s.W..Ws.s.W...s.s.......Ws...s..s.W.sWs.....s....s...s.s...Ws...s......W..W........s..W.W.....Ws...20000 mean training reward: 12.26
# done
# CPU times: user 4h 7min 31s, sys: 42min 32s, total: 4h 50min 4s
# Wall time: 4h 51min 36s

# %%
## If there is an error resize the wins and num_episodes to still be able to print
if(len(rewards)!=num_episodes):
  new_lenght = len(rewards)
  num_episodes = new_lenght
  wins = wins[:new_lenght]

# %% [markdown]
# # Plot results
#
# Visualize training statistics

# %%
# Plot training statistics
def moving_average(a, n=10) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

plt.figure(figsize=(16, 9))
#Plot training rewards
plt.subplot(511)
plt.title('training rewards')
plt.plot(range(1, num_episodes+1), rewards)
plt.plot(range(1, num_episodes+1), moving_average(rewards))
plt.xlim([0, num_episodes])
#Plot wins
plt.subplot(512)
plt.title('wins')
plt.plot(range(1, num_episodes+1), wins)
plt.plot(range(1, num_episodes+1), moving_average(wins))
plt.xlim([0, num_episodes])
#Plot training lengths
plt.subplot(513)
plt.title('training lengths')
plt.plot(range(1, num_episodes+1), lengths)
plt.plot(range(1, num_episodes+1), moving_average(lengths))
plt.xlim([0, num_episodes])
#Plot training loss
plt.subplot(514)
plt.title('training loss')
plt.plot(range(1, num_episodes+1), losses)
plt.plot(range(1, num_episodes+1), moving_average(losses))
plt.xlim([0, num_episodes])
#Plot epsilon
plt.subplot(515)
plt.title('epsilon')
plt.plot(range(1, num_episodes+1), epsilons)
plt.xlim([0, num_episodes])

plt.tight_layout(); plt.show()

#Plot actions done in each episode
import pandas as pd
from collections import Counter

size = len(actionlog)
y = np.zeros((size,6))

for i in range(size):
  n = Counter(actionlog[i])
  for j in range(6):
    y[i][j] = n[j]
    
x = np.arange(size)
df = pd.DataFrame(y, index=x)

df = df.divide(df.sum(axis=1), axis=0)
ax = df.plot(kind='area', stacked=True, title='Actions over the episodes', figsize=(19.5, 2),legend = 'reverse')

ax.set_xlabel('Episodes'); ax.set_ylabel('Percent (%)')
ax.margins(0, 0) # Set margins to avoid "whitespace"

plt.show()

# %% [markdown]
# # Save file
#
# Save trainned models and download it in a file

# %%
#Save trained model
from google.colab import files
torch.save(agents[3].qnet.state_dict(), "simple_modelB.pth.tar")
files.download( "simple_modelB.pth.tar" )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b8184e43ee94> in <module>()
#       1 from google.colab import files
#       2 torch.save(agents[3].qnet.state_dict(), "simple_modelB.pth.tar")
# ----> 3 files.download( "simple_modelB.pth.tar" )
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# # Animation
#
# Use emojii render to visualize a game with the pre-trainned agent.

# %%
lookup = ['Stop', 'Up', 'Down', 'Left', 'Right', 'Bomb']

# %%
import emoji

def myRender(stage):
  for i in stage:
    for j in i:
      if(j==0): # free ground
        j = emoji.emojize(":white_question_mark:")
        #j = emoji.emojize(":white_large_square:")
      elif(j==1): # stone wall
        j = emoji.emojize(":mountain:")
      elif(j==2): # wooden wall
        j = emoji.emojize(":seedling:")
      elif(j==3): # bomb
        j = emoji.emojize(":bomb:")
      elif(j==4): # fire     
        j = emoji.emojize(":fire:")
      # 5 is fog
      
      #power ups
      elif(j==6): # extra bombs item     
        j = emoji.emojize(":pistol:")
      elif(j==7): # extra firepower     
        j = emoji.emojize(":collision:")
      elif(j==8): # kick     
        j = emoji.emojize(":running_shoe:")
      
        
      elif(j==10 or j==11 or j==12): #opponent
        j = emoji.emojize(":smiling_face_with_horns:")
      elif(j==13): #our agent
        j = emoji.emojize(":smiling_face_with_sunglasses:")

      print(j, end = "")
    print("")    

this_stage = s[3]['board']
myRender(this_stage)
# Out:
# ❔⛰❔⛰⛰❔❔⛰⛰⛰🌱
# ⛰🔥🔥🔥🔥❔❔❔🔥🔥⛰
# ❔❔❔🔥❔❔⛰❔⛰🔥🌱
# ⛰❔❔🔥⛰❔🌱🌱⛰❔⛰
# ⛰❔❔⛰❔❔❔⛰⛰🌱❔
# ❔❔😈❔❔❔⛰🌱⛰🌱🌱
# ❔💣⛰🌱❔⛰❔🌱🌱🌱🌱
# ⛰❔❔💣⛰🌱🌱❔⛰❔❔
# ⛰😈⛰⛰⛰⛰🌱⛰❔❔❔
# ⛰❔❔❔❔❔🔫❔❔❔⛰
# 🌱⛰❔⛰❔🔫🌱❔❔⛰❔

# %%
from IPython.display import clear_output
import time

num_episodes = 1
shapedreward = RewardsShaper()

rewards, lengths, losses, epsilons, wins, actionlog = [], [], [], [], [0] * num_episodes, []
for i in range(num_episodes):
    # init new episode
    s, ep_reward, ep_loss, ep_actions = env.reset(), 0, 0, []
    q_values = []
    r = 0

    for j in range(episode_limit):
        actions = env.act(s)
        s1, r, done, info = env.step(actions)
        
        clear_output()
        #print(actions[3],lookup[actions[3]])
        #if(j!=0):
        #  print(np.round_(agents[3].Q.data.cpu().numpy()))
        print()
        myRender(s[3]['board'])
        print()
        time.sleep(1.5)
        
        if(13 in s[3]['alive']):
            shaped, suicude = shapedreward.run(s, actions, s1, done, info)
            ep_reward += shaped
            r[3] += shaped
            loss = agents[3].afterstep(s1[3], r[3], actions[3])

            ep_loss += loss.item()
            q_values.append(agents[3].Q)
        else:
          done = True
          
        s = s1
        if done: break

    # episode is finished 
    if("winners" in info):
      if(3 in info["winners"]):
        ep_reward += 1
        wins[i] = 1
      else:
        ep_reward -= 1

    print(".",end="")
# Out:
# ❔🌱⛰🌱❔⛰⛰❔⛰⛰🌱
# 🌱💣❔❔🌱🌱🌱❔😎💣⛰
# ⛰❔❔❔🌱❔⛰❔⛰❔🌱
# 🌱❔😈❔❔❔⛰⛰🌱❔❔
# ❔🌱🌱❔❔🌱🌱❔❔🌱⛰
# ⛰🌱❔❔🌱❔⛰⛰🌱🌱⛰
# ⛰🌱⛰⛰🌱⛰❔🌱🌱🌱🌱
# ❔😈❔⛰❔⛰🌱❔⛰❔⛰
# ⛰❔⛰🌱❔🌱🌱⛰❔❔⛰
# ⛰❔💣❔🌱🌱🌱❔😈💣⛰
# 🌱⛰🌱❔⛰⛰🌱⛰⛰⛰❔
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5188556e26d8> in <module>()
#      23         myRender(s[3]['board'])
#      24         print()
# ---> 25         time.sleep(1.5)
#      26
#      27         if(13 in s[3]['alive']):
#
# KeyboardInterrupt:
